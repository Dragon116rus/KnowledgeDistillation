# %% [markdown]
# Downloanding third-party code for resnet model

# %%
# !wget https://raw.githubusercontent.com/akamaster/pytorch_resnet_cifar10/d1872999394aa0c234e8d855e3c853eb061f7c06/resnet.py
# Out:
# --2020-02-08 09:17:35--  https://raw.githubusercontent.com/akamaster/pytorch_resnet_cifar10/d1872999394aa0c234e8d855e3c853eb061f7c06/resnet.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5001 (4.9K) [text/plain]
# Saving to: ‘resnet.py’
#
# resnet.py           100%[===================>]   4.88K  --.-KB/s    in 0s
#
# 2020-02-08 09:17:36 (59.4 MB/s) - ‘resnet.py’ saved [5001/5001]

# %% [markdown]
# Downloading/uploading with kaggle kernel

# %%
# !mkdir -p models

# upload model to google drive
def upload_model(source_name, saving_name):
  # !cp {source_name} "models/{saving_name}" 

def upload_logs():
    pass

# %%
# !cp -r '../input/cinic10/train' train
# !cp -r '../input/cinic10/test' test
# !cp -r '../input/cinic10/valid' valid

# %% [markdown]
# Libs importing

# %%
import gc
import os
import datetime

import numpy as np
np.random.seed(42)

import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils as utils
from torch.utils.data import Subset, ConcatDataset, DataLoader

from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import accuracy_score

from resnet import resnet20, BasicBlock, _weights_init, resnet32, resnet56, resnet44, ResNet

def resnet7():return ResNet(BasicBlock, [1, 1, 1])

# %% [markdown]
# Declaration of utils

# %%
class AverageMeter:
  """Class for computing average values
  """    
  def __init__(self):
    """Init class
    """      
    self.sum_ = 0
    self.count = 0
  
  def update(self, val, count=1):
    """Add new value to track
    
    Arguments:
        val {float} -- new value
    
    Keyword Arguments:
        count {int} -- weigth of val (default: {1})
    """      
    self.sum_ += val
    self.count += count

  def average(self):
    """return average value for given values
    """      
    return self.sum_ / self.count

# %%
class TensorBoardLogger:
    """Class for logging into TensorBoard
    """    
    def __init__(self, log_dir, dataset, experiment_name):
        """Init logger
        
        Arguments:
            log_dir {string} -- log dir
            dataset {string} -- name of dataset
            experiment_name {string} -- name of experiment
        """        
        current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
        log_dir_full = os.path.join(log_dir, dataset, current_time, experiment_name)
        self.writer = tf.summary.create_file_writer(log_dir_full)
        self.step_ = 0
        
    def log_scalar(self, tag, value, step=None, description=None):
        """Log scalar
        
        Arguments:
            tag {string} -- name of variable to log
            value {float} -- value of variable
        
        Keyword Arguments:
            step {int} -- current epoch number (default: {None})
            description {string} -- [description] (default: {None})
        """        
        if step is None:
            step = self.step_
        with self.writer.as_default():
            tf.summary.scalar(tag, value, step=step, description=description)
            
    def step(self):
        """Increase epoch number by 1
        """        
        self.step_+=1

# %% [markdown]
# Dataset declaration

# %%
batch_size = 64
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

# augmentation and normaliztion for training
transform_train = transforms.Compose(
    [
     transforms.RandomHorizontalFlip(p=0.5),
     transforms.RandomCrop(32, 4),
     transforms.ToTensor(),
     normalize
     ])

# only normalization for testing
transform_test = transforms.Compose(
    [
     transforms.ToTensor(),
     normalize
     ])


trainset = torchvision.datasets.ImageFolder(root='train', transform=transform_train)
valset = torchvision.datasets.ImageFolder(root='valid', transform=transform_test)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2,
                                          pin_memory=True, 
                                          )
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size,
                                          shuffle=True, num_workers=2,
                                          pin_memory=True, 
                                          )

testset = torchvision.datasets.ImageFolder(root='test', transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2,
                                         pin_memory=True, )

# %%
len(testloader), len(valloader), len(trainloader)
# Out:
# (1407, 1407, 1407)

# %% [markdown]
# Training functions definition

# %%
def accuracy_minibatch(outputs, labels):
  if isinstance(outputs, torch.Tensor):
    outputs = outputs.cpu().detach().numpy()
  if isinstance(labels, torch.Tensor):
    labels = labels.cpu().detach().numpy()
  
  predict_= np.argmax(outputs, axis=1)
  true_labels_= labels
  micro_acc_score = accuracy_score(predict_, true_labels_)
  return micro_acc_score

# %%
def validate(net, testloader, logger=None, compression_f=None, verbose=True, prename="val"):
  """Function for compute metrics on validation set
  
  Arguments:
      net {torch net} -- model
      testloader {DataLoader} -- set to validation
      
  Keyword Arguments:
      logger {TensorBoardLogger} -- logger (default: {None})
      compression_f {function} -- function to preprocess input (default: {None})
      verbose {bool} -- show metrics (default: {True})
      prename {string} -- prename to name of metric (default: {"val"})
  
  Returns:
      [floats] -- scores for computing metrics
  """  
  # change net to evaluation mode
  net.eval()
  ce_loss_avg = AverageMeter()
  accuracy_score_avg = AverageMeter()
  criterion = nn.CrossEntropyLoss()
  
  # evaluate dataset
  for i, data in enumerate(testloader, 0):
    inputs, labels = data
    inputs, labels = inputs.cuda(), labels.cuda()
    current_batch_size = len(labels)

    if compression_f is not None:
      inputs = compression_f(inputs)
    outputs = net(inputs)
    loss = criterion(outputs, labels).cpu().detach().numpy()
    
    micro_acc_score = accuracy_minibatch(outputs, labels)

    accuracy_score_avg.update(micro_acc_score*current_batch_size, current_batch_size)
    ce_loss_avg.update(loss.item()*current_batch_size, current_batch_size)

  accuracy = accuracy_score_avg.average()
  ce_loss = ce_loss_avg.average()
  scores = {"%s_accuracy"%prename:accuracy, "%s_ce_loss"%prename:ce_loss}
  
  # log scores
  for name, score in scores.items():
    if logger:
      logger.log_scalar(name, score)
    if verbose:
      print(name, score)
  
  if verbose:
    print("__________________")
  # change net to training mode
  net.train()
  return scores

# %%
def train_classic_approach(
    net, 
    trainloader, 
    testloader, 
    epoches=300,
    compression_f=None, 
    verbose=True, 
    return_best=True,
    logger=None,
    init_lr=0.1
    ):
  """Training using classic approach
  
  Arguments:
      net {torch model} -- model
      trainloader {DataLoader} -- train set
      testloader {DataLoader} -- test set
  
  Keyword Arguments:
      epoches {int} -- epocs to train (default: {300})
      compression_f {[type]} -- function to preprocess input (default: {None})
      verbose {bool} -- show metrics (default: {True})
      return_best {bool} -- return best model (default: {True})
      logger {TensorBoardLogger} -- logger (default: {None})
      init_lr {float} -- initial learning rate (default: {0.1})
  
  Returns:
      torch model -- last or best model
  """  
  # change net to training mode
  net.train()
  # use gpu to train
  net.cuda()
  # loss of training
  criterion = nn.CrossEntropyLoss()
  
  optimizer = torch.optim.SGD(
      net.parameters(), 
      lr=init_lr,
      momentum=0.9,
      weight_decay=1e-4)
  scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, threshold=0.001, patience=4)

  validation_scores = []
  
  os.makedirs("models", exist_ok=True)
  saving_path_template = "models/model_epoch%s.dms"

  for epoch in range(epoches):  # loop over the dataset multiple times
      saving_name = saving_path_template%epoch
      
      loss_avg = AverageMeter()
      accuracy_score_avg = AverageMeter()

      for i, data in enumerate(trainloader, 1):
          # get the inputs; data is a list of [inputs, labels]
          inputs, labels = data
          current_batch_size = len(labels)
          if compression_f:
            inputs = compression_f(inputs)
          inputs, labels = inputs.cuda(), labels.cuda()

          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = net(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          micro_acc_score = accuracy_minibatch(outputs, labels)

          loss_avg.update(loss.item()*current_batch_size, current_batch_size)
          accuracy_score_avg.update(micro_acc_score*current_batch_size, current_batch_size)

      if verbose:
        print(saving_name)
        print('loss {:.3}'.format(loss_avg.average()))
        print('current lr {:.3e}'.format(optimizer.param_groups[0]['lr']))
        print("__________________")
      
      # clear memory 
      gc.collect()
      torch.cuda.empty_cache()  
      
      validation_score = validate(net, valloader, logger=logger, verbose=verbose, compression_f=compression_f)
      accuracy = validation_score['val_accuracy']
      
      validation_scores.append(accuracy)
      torch.save(net.state_dict(), saving_name)
      
      if logger:
        logger.log_scalar("ce_loss", loss_avg.average())
        logger.log_scalar("accuracy", accuracy_score_avg.average())
        logger.step()
      scheduler.step(loss_avg.average())

  best_epoch = np.argmax(validation_scores)
  if return_best:
    choosen_epoch = best_epoch
  else:
    choosen_epoch = epoch
  if verbose:
    print("choosen epoch:", choosen_epoch, ",", "score:", validation_scores[choosen_epoch])
    print("best epoch:", best_epoch, ",", "score:", validation_scores[best_epoch])
  model_name = saving_path_template%choosen_epoch
  net.load_state_dict(torch.load(model_name))
  return net

# %%
for net, name in [
    (resnet20(), "resnet20_classic.pt"), 
    (resnet32(), "resnet32_classic.pt"), 
]:
  logger = TensorBoardLogger("logs", "cinic10", name)
  net = train_classic_approach(net, trainloader, valloader, logger=logger, return_best=True, epoches=150)
  print("-----------------")
  print(name)
  validate(net, testloader, prename="test")
  validate(net, valloader, prename="val")
  validate(net, trainloader, prename="train")
  print("----------------")
  torch.save(net.state_dict(),name)
  upload_model(name, name)
  upload_logs()
# Out:
# models/model_epoch0.dms
# loss 1.66
# current lr 1.000e-01
# __________________
# val_accuracy 0.4469666666666667
# val_ce_loss 1.5165933913760714
# __________________
# models/model_epoch1.dms
# loss 1.31
# current lr 1.000e-01
# __________________
# val_accuracy 0.49194444444444446
# val_ce_loss 1.4608890915764703
# __________________
# models/model_epoch2.dms
# loss 1.16
# current lr 1.000e-01
# __________________
# val_accuracy 0.6122555555555556
# val_ce_loss 1.1029332371817695
# __________________
# models/model_epoch3.dms
# loss 1.07
# current lr 1.000e-01
# __________________
# val_accuracy 0.6263222222222222
# val_ce_loss 1.0366073227140638
# __________________
# models/model_epoch4.dms
# loss 1.01
# current lr 1.000e-01
# __________________
# val_accuracy 0.5937666666666667
# val_ce_loss 1.2511868357552423
# __________________
# models/model_epoch5.dms
# loss 0.965
# current lr 1.000e-01
# __________________
# val_accuracy 0.6193666666666666
# val_ce_loss 1.1084816803826225
# __________________
# models/model_epoch6.dms
# loss 0.937
# current lr 1.000e-01
# __________________
# val_accuracy 0.6041333333333333
# val_ce_loss 1.1951829695595635
# __________________
# models/model_epoch7.dms
# loss 0.91
# current lr 1.000e-01
# __________________
# val_accuracy 0.6538555555555555
# val_ce_loss 0.9881187608506945
# __________________
# models/model_epoch8.dms
# loss 0.885
# current lr 1.000e-01
# __________________
# val_accuracy 0.6858777777777778
# val_ce_loss 0.8826174791971843
# __________________
# models/model_epoch9.dms
# loss 0.862
# current lr 1.000e-01
# __________________
# val_accuracy 0.6592333333333333
# val_ce_loss 1.0148524691581726
# __________________
# models/model_epoch10.dms
# loss 0.847
# current lr 1.000e-01
# __________________
# val_accuracy 0.674
# val_ce_loss 0.9675709469477336
# __________________
# models/model_epoch11.dms
# loss 0.836
# current lr 1.000e-01
# __________________
# val_accuracy 0.7012111111111111
# val_ce_loss 0.8506955532603794
# __________________
# models/model_epoch12.dms
# loss 0.822
# current lr 1.000e-01
# __________________
# val_accuracy 0.6796
# val_ce_loss 0.941894452963935
# __________________
# models/model_epoch13.dms
# loss 0.807
# current lr 1.000e-01
# __________________
# val_accuracy 0.6974333333333333
# val_ce_loss 0.8775375824186536
# __________________
# models/model_epoch14.dms
# loss 0.801
# current lr 1.000e-01
# __________________
# val_accuracy 0.6929444444444445
# val_ce_loss 0.8801125047895644
# __________________
# models/model_epoch15.dms
# loss 0.792
# current lr 1.000e-01
# __________________
# val_accuracy 0.6909111111111111
# val_ce_loss 0.9139185758696662
# __________________
# models/model_epoch16.dms
# loss 0.784
# current lr 1.000e-01
# __________________
# val_accuracy 0.7002777777777778
# val_ce_loss 0.8750438525199891
# __________________
# models/model_epoch17.dms
# loss 0.782
# current lr 1.000e-01
# __________________
# val_accuracy 0.6731666666666667
# val_ce_loss 0.9634445210986667
# __________________
# models/model_epoch18.dms
# loss 0.768
# current lr 1.000e-01
# __________________
# val_accuracy 0.6720222222222222
# val_ce_loss 0.9502622224171956
# __________________
# models/model_epoch19.dms
# loss 0.767
# current lr 1.000e-01
# __________________
# val_accuracy 0.7058888888888889
# val_ce_loss 0.8502128091812133
# __________________
# models/model_epoch20.dms
# loss 0.758
# current lr 1.000e-01
# __________________
# val_accuracy 0.6828777777777778
# val_ce_loss 0.9543533394283719
# __________________
# models/model_epoch21.dms
# loss 0.754
# current lr 1.000e-01
# __________________
# val_accuracy 0.6994888888888889
# val_ce_loss 0.8794314033720229
# __________________
# models/model_epoch22.dms
# loss 0.751
# current lr 1.000e-01
# __________________
# val_accuracy 0.6762
# val_ce_loss 0.950275455517239
# __________________
# models/model_epoch23.dms
# loss 0.748
# current lr 1.000e-01
# __________________
# val_accuracy 0.6974888888888889
# val_ce_loss 0.8922868864059448
# __________________
# models/model_epoch24.dms
# loss 0.741
# current lr 1.000e-01
# __________________
# val_accuracy 0.7152
# val_ce_loss 0.8204284195899963
# __________________
# models/model_epoch25.dms
# loss 0.742
# current lr 1.000e-01
# __________________
# val_accuracy 0.7044
# val_ce_loss 0.8798919577492608
# __________________
# models/model_epoch26.dms
# loss 0.735
# current lr 1.000e-01
# __________________
# val_accuracy 0.6822555555555555
# val_ce_loss 0.8898326155556573
# __________________
# models/model_epoch27.dms
# loss 0.734
# current lr 1.000e-01
# __________________
# val_accuracy 0.7025
# val_ce_loss 0.8531350373586019
# __________________
# models/model_epoch28.dms
# loss 0.732
# current lr 1.000e-01
# __________________
# val_accuracy 0.6984555555555556
# val_ce_loss 0.8612862871805826
# __________________
# models/model_epoch29.dms
# loss 0.727
# current lr 1.000e-01
# __________________
# val_accuracy 0.7200333333333333
# val_ce_loss 0.8006151918941073
# __________________
# models/model_epoch30.dms
# loss 0.729
# current lr 1.000e-01
# __________________
# val_accuracy 0.7148444444444444
# val_ce_loss 0.8118378366046481
# __________________
# models/model_epoch31.dms
# loss 0.719
# current lr 1.000e-01
# __________________
# val_accuracy 0.7225888888888888
# val_ce_loss 0.7897100856992934
# __________________
# models/model_epoch32.dms
# loss 0.721
# current lr 1.000e-01
# __________________
# val_accuracy 0.7059888888888889
# val_ce_loss 0.8460261494636535
# __________________
# models/model_epoch33.dms
# loss 0.716
# current lr 1.000e-01
# __________________
# val_accuracy 0.7109555555555556
# val_ce_loss 0.8596191850238376
# __________________
# models/model_epoch34.dms
# loss 0.72
# current lr 1.000e-01
# __________________
# val_accuracy 0.7177777777777777
# val_ce_loss 0.8051274518966675
# __________________
# models/model_epoch35.dms
# loss 0.72
# current lr 1.000e-01
# __________________
# val_accuracy 0.7060777777777778
# val_ce_loss 0.8441232417000665
# __________________
# models/model_epoch36.dms
# loss 0.709
# current lr 1.000e-01
# __________________
# val_accuracy 0.6667666666666666
# val_ce_loss 1.0135390732394325
# __________________
# models/model_epoch37.dms
# loss 0.712
# current lr 1.000e-01
# __________________
# val_accuracy 0.7442111111111112
# val_ce_loss 0.7454506385591295
# __________________
# models/model_epoch38.dms
# loss 0.709
# current lr 1.000e-01
# __________________
# val_accuracy 0.7048333333333333
# val_ce_loss 0.8711664455890655
# __________________
# models/model_epoch39.dms
# loss 0.707
# current lr 1.000e-01
# __________________
# val_accuracy 0.7138555555555556
# val_ce_loss 0.8266741510073344
# __________________
# models/model_epoch40.dms
# loss 0.708
# current lr 1.000e-01
# __________________
# val_accuracy 0.7187444444444444
# val_ce_loss 0.8153374935574002
# __________________
# models/model_epoch41.dms
# loss 0.705
# current lr 1.000e-01
# __________________
# val_accuracy 0.7154444444444444
# val_ce_loss 0.8228372999615139
# __________________
# models/model_epoch42.dms
# loss 0.706
# current lr 1.000e-01
# __________________
# val_accuracy 0.7334333333333334
# val_ce_loss 0.7672772993511624
# __________________
# models/model_epoch43.dms
# loss 0.704
# current lr 1.000e-01
# __________________
# val_accuracy 0.7326111111111111
# val_ce_loss 0.7649328665839301
# __________________
# models/model_epoch44.dms
# loss 0.698
# current lr 1.000e-01
# __________________
# val_accuracy 0.7049333333333333
# val_ce_loss 0.8595961461808946
# __________________
# models/model_epoch45.dms
# loss 0.701
# current lr 1.000e-01
# __________________
# val_accuracy 0.7215555555555555
# val_ce_loss 0.7952678384092119
# __________________
# models/model_epoch46.dms
# loss 0.696
# current lr 1.000e-01
# __________________
# val_accuracy 0.7404333333333334
# val_ce_loss 0.7418351030137804
# __________________
# models/model_epoch47.dms
# loss 0.694
# current lr 1.000e-01
# __________________
# val_accuracy 0.7206
# val_ce_loss 0.8332873070928786
# __________________
# models/model_epoch48.dms
# loss 0.696
# current lr 1.000e-01
# __________________
# val_accuracy 0.7129555555555556
# val_ce_loss 0.855615013800727
# __________________
# models/model_epoch49.dms
# loss 0.695
# current lr 1.000e-01
# __________________
# val_accuracy 0.7042111111111111
# val_ce_loss 0.8611576213783688
# __________________
# models/model_epoch50.dms
# loss 0.693
# current lr 1.000e-01
# __________________
# val_accuracy 0.7414
# val_ce_loss 0.7355127766079372
# __________________
# models/model_epoch51.dms
# loss 0.69
# current lr 1.000e-01
# __________________
# val_accuracy 0.7280333333333333
# val_ce_loss 0.7673146515528361
# __________________
# models/model_epoch52.dms
# loss 0.695
# current lr 1.000e-01
# __________________
# val_accuracy 0.7326222222222222
# val_ce_loss 0.753368395614624
# __________________
# models/model_epoch53.dms
# loss 0.692
# current lr 1.000e-01
# __________________
# val_accuracy 0.7324666666666667
# val_ce_loss 0.7750766114128961
# __________________
# models/model_epoch54.dms
# loss 0.692
# current lr 1.000e-01
# __________________
# val_accuracy 0.7139666666666666
# val_ce_loss 0.827032516585456
# __________________
# models/model_epoch55.dms
# loss 0.692
# current lr 1.000e-01
# __________________
# val_accuracy 0.7322555555555555
# val_ce_loss 0.7492188419659932
# __________________
# models/model_epoch56.dms
# loss 0.685
# current lr 1.000e-01
# __________________
# val_accuracy 0.7226444444444444
# val_ce_loss 0.8153500379244486
# __________________
# models/model_epoch57.dms
# loss 0.688
# current lr 1.000e-01
# __________________
# val_accuracy 0.6935
# val_ce_loss 0.8687081370830536
# __________________
# models/model_epoch58.dms
# loss 0.686
# current lr 1.000e-01
# __________________
# val_accuracy 0.7292777777777778
# val_ce_loss 0.7752068867153592
# __________________
# models/model_epoch59.dms
# loss 0.684
# current lr 1.000e-01
# __________________
# val_accuracy 0.7120111111111112
# val_ce_loss 0.8849333666218652
# __________________
# models/model_epoch60.dms
# loss 0.684
# current lr 1.000e-01
# __________________
# val_accuracy 0.7164
# val_ce_loss 0.8272408896976047
# __________________
# models/model_epoch61.dms
# loss 0.681
# current lr 1.000e-01
# __________________
# val_accuracy 0.7377444444444444
# val_ce_loss 0.7796959098074171
# __________________
# models/model_epoch62.dms
# loss 0.682
# current lr 1.000e-01
# __________________
# val_accuracy 0.7253333333333334
# val_ce_loss 0.7800449615902371
# __________________
# models/model_epoch63.dms
# loss 0.684
# current lr 1.000e-01
# __________________
# val_accuracy 0.7291777777777778
# val_ce_loss 0.7716628360218472
# __________________
# models/model_epoch64.dms
# loss 0.681
# current lr 1.000e-01
# __________________
# val_accuracy 0.7441888888888889
# val_ce_loss 0.7269415770742629
# __________________
# models/model_epoch65.dms
# loss 0.68
# current lr 1.000e-01
# __________________
# val_accuracy 0.7422777777777778
# val_ce_loss 0.7203762610223559
# __________________
# models/model_epoch66.dms
# loss 0.681
# current lr 1.000e-01
# __________________
# val_accuracy 0.7326444444444444
# val_ce_loss 0.7806948693169488
# __________________
# models/model_epoch67.dms
# loss 0.522
# current lr 1.000e-02
# __________________
# val_accuracy 0.8030444444444444
# val_ce_loss 0.5662159832000733
# __________________
# models/model_epoch68.dms
# loss 0.482
# current lr 1.000e-02
# __________________
# val_accuracy 0.8070666666666667
# val_ce_loss 0.5521236964967515
# __________________
# models/model_epoch69.dms
# loss 0.467
# current lr 1.000e-02
# __________________
# val_accuracy 0.8103888888888889
# val_ce_loss 0.5434517621252272
# __________________
# models/model_epoch70.dms
# loss 0.455
# current lr 1.000e-02
# __________________
# val_accuracy 0.8149
# val_ce_loss 0.5363043355782827
# __________________
# models/model_epoch71.dms
# loss 0.445
# current lr 1.000e-02
# __________________
# val_accuracy 0.8142444444444444
# val_ce_loss 0.5381805733574762
# __________________
# models/model_epoch72.dms
# loss 0.44
# current lr 1.000e-02
# __________________
# val_accuracy 0.8147555555555556
# val_ce_loss 0.535054333919949
# __________________
# models/model_epoch73.dms
# loss 0.432
# current lr 1.000e-02
# __________________
# val_accuracy 0.8121555555555555
# val_ce_loss 0.5475128611988491
# __________________
# models/model_epoch74.dms
# loss 0.425
# current lr 1.000e-02
# __________________
# val_accuracy 0.8121444444444444
# val_ce_loss 0.5453599668820699
# __________________
# models/model_epoch75.dms
# loss 0.425
# current lr 1.000e-02
# __________________
# val_accuracy 0.8135
# val_ce_loss 0.5461895848857032
# __________________
# models/model_epoch76.dms
# loss 0.415
# current lr 1.000e-02
# __________________
# val_accuracy 0.8142333333333334
# val_ce_loss 0.543149711449941
# __________________
# models/model_epoch77.dms
# loss 0.413
# current lr 1.000e-02
# __________________
# val_accuracy 0.8104222222222223
# val_ce_loss 0.5524838078180949
# __________________
# models/model_epoch78.dms
# loss 0.41
# current lr 1.000e-02
# __________________
# val_accuracy 0.8105666666666667
# val_ce_loss 0.5511507993804083
# __________________
# models/model_epoch79.dms
# loss 0.408
# current lr 1.000e-02
# __________________
# val_accuracy 0.8139666666666666
# val_ce_loss 0.5509834948751662
# __________________
# models/model_epoch80.dms
# loss 0.403
# current lr 1.000e-02
# __________________
# val_accuracy 0.8130111111111111
# val_ce_loss 0.5600359436776903
# __________________
# models/model_epoch81.dms
# loss 0.402
# current lr 1.000e-02
# __________________
# val_accuracy 0.8121111111111111
# val_ce_loss 0.5581200926250882
# __________________
# models/model_epoch82.dms
# loss 0.398
# current lr 1.000e-02
# __________________
# val_accuracy 0.8128333333333333
# val_ce_loss 0.5521341345893012
# __________________
# models/model_epoch83.dms
# loss 0.396
# current lr 1.000e-02
# __________________
# val_accuracy 0.8094111111111111
# val_ce_loss 0.5655313175095452
# __________________
# models/model_epoch84.dms
# loss 0.394
# current lr 1.000e-02
# __________________
# val_accuracy 0.8130666666666667
# val_ce_loss 0.555806159321467
# __________________
# models/model_epoch85.dms
# loss 0.389
# current lr 1.000e-02
# __________________
# val_accuracy 0.8113777777777778
# val_ce_loss 0.5600483382436964
# __________________
# models/model_epoch86.dms
# loss 0.391
# current lr 1.000e-02
# __________________
# val_accuracy 0.8122444444444444
# val_ce_loss 0.5609974565929837
# __________________
# models/model_epoch87.dms
# loss 0.388
# current lr 1.000e-02
# __________________
# val_accuracy 0.8131
# val_ce_loss 0.5592979396184286
# __________________
# models/model_epoch88.dms
# loss 0.387
# current lr 1.000e-02
# __________________
# val_accuracy 0.8055444444444444
# val_ce_loss 0.582033249727885
# __________________
# models/model_epoch89.dms
# loss 0.387
# current lr 1.000e-02
# __________________
# val_accuracy 0.8134888888888889
# val_ce_loss 0.5559174226813847
# __________________
# models/model_epoch90.dms
# loss 0.388
# current lr 1.000e-02
# __________________
# val_accuracy 0.8076333333333333
# val_ce_loss 0.5790758438110352
# __________________
# models/model_epoch91.dms
# loss 0.386
# current lr 1.000e-02
# __________________
# val_accuracy 0.8103777777777778
# val_ce_loss 0.5717093155860901
# __________________
# models/model_epoch92.dms
# loss 0.385
# current lr 1.000e-02
# __________________
# val_accuracy 0.8090666666666667
# val_ce_loss 0.5724761204507616
# __________________
# models/model_epoch93.dms
# loss 0.384
# current lr 1.000e-02
# __________________
# val_accuracy 0.8046
# val_ce_loss 0.5908104110823738
# __________________
# models/model_epoch94.dms
# loss 0.38
# current lr 1.000e-02
# __________________
# val_accuracy 0.8088333333333333
# val_ce_loss 0.5853503604571024
# __________________
# models/model_epoch95.dms
# loss 0.383
# current lr 1.000e-02
# __________________
# val_accuracy 0.8086666666666666
# val_ce_loss 0.5798545614454481
# __________________
# models/model_epoch96.dms
# loss 0.379
# current lr 1.000e-02
# __________________
# val_accuracy 0.8074222222222223
# val_ce_loss 0.5807949533144633
# __________________
# models/model_epoch97.dms
# loss 0.379
# current lr 1.000e-02
# __________________
# val_accuracy 0.8045
# val_ce_loss 0.6020739054361979
# __________________
# models/model_epoch98.dms
# loss 0.379
# current lr 1.000e-02
# __________________
# val_accuracy 0.8081666666666667
# val_ce_loss 0.585293588648902
# __________________
# models/model_epoch99.dms
# loss 0.38
# current lr 1.000e-02
# __________________
# val_accuracy 0.8065888888888889
# val_ce_loss 0.5878322155422635
# __________________
# models/model_epoch100.dms
# loss 0.376
# current lr 1.000e-02
# __________________
# val_accuracy 0.7989333333333334
# val_ce_loss 0.6353886675304836
# __________________
# models/model_epoch101.dms
# loss 0.379
# current lr 1.000e-02
# __________________
# val_accuracy 0.8046888888888889
# val_ce_loss 0.5938414589564005
# __________________
# models/model_epoch102.dms
# loss 0.376
# current lr 1.000e-02
# __________________
# val_accuracy 0.8061111111111111
# val_ce_loss 0.5977978107399411
# __________________
# models/model_epoch103.dms
# loss 0.379
# current lr 1.000e-02
# __________________
# val_accuracy 0.8044444444444444
# val_ce_loss 0.5955005330880483
# __________________
# models/model_epoch104.dms
# loss 0.379
# current lr 1.000e-02
# __________________
# val_accuracy 0.8034222222222223
# val_ce_loss 0.5968384949790106
# __________________
# models/model_epoch105.dms
# loss 0.376
# current lr 1.000e-02
# __________________
# val_accuracy 0.7994888888888889
# val_ce_loss 0.6233941900783115
# __________________
# models/model_epoch106.dms
# loss 0.378
# current lr 1.000e-02
# __________________
# val_accuracy 0.8059
# val_ce_loss 0.583334351656172
# __________________
# models/model_epoch107.dms
# loss 0.378
# current lr 1.000e-02
# __________________
# val_accuracy 0.8035777777777777
# val_ce_loss 0.6148422052913242
# __________________
# models/model_epoch108.dms
# loss 0.317
# current lr 1.000e-03
# __________________
# val_accuracy 0.8232777777777778
# val_ce_loss 0.5412033779886034
# __________________
# models/model_epoch109.dms
# loss 0.294
# current lr 1.000e-03
# __________________
# val_accuracy 0.8245888888888889
# val_ce_loss 0.5395834803687202
# __________________
# models/model_epoch110.dms
# loss 0.288
# current lr 1.000e-03
# __________________
# val_accuracy 0.8251444444444445
# val_ce_loss 0.5403345758120219
# __________________
# models/model_epoch111.dms
# loss 0.283
# current lr 1.000e-03
# __________________
# val_accuracy 0.8247888888888889
# val_ce_loss 0.5486792582511902
# __________________
# models/model_epoch112.dms
# loss 0.278
# current lr 1.000e-03
# __________________
# val_accuracy 0.8250444444444445
# val_ce_loss 0.5499735983689626
# __________________
# models/model_epoch113.dms
# loss 0.276
# current lr 1.000e-03
# __________________
# val_accuracy 0.8255666666666667
# val_ce_loss 0.5526150140974256
# __________________
# models/model_epoch114.dms
# loss 0.273
# current lr 1.000e-03
# __________________
# val_accuracy 0.8246
# val_ce_loss 0.5598143148740132
# __________________
# models/model_epoch115.dms
# loss 0.27
# current lr 1.000e-03
# __________________
# val_accuracy 0.8259333333333333
# val_ce_loss 0.5549910763157738
# __________________
# models/model_epoch116.dms
# loss 0.268
# current lr 1.000e-03
# __________________
# val_accuracy 0.8247
# val_ce_loss 0.5568550935851203
# __________________
# models/model_epoch117.dms
# loss 0.266
# current lr 1.000e-03
# __________________
# val_accuracy 0.8236444444444444
# val_ce_loss 0.5629564385679033
# __________________
# models/model_epoch118.dms
# loss 0.266
# current lr 1.000e-03
# __________________
# val_accuracy 0.8243222222222222
# val_ce_loss 0.5625914275593228
# __________________
# models/model_epoch119.dms
# loss 0.26
# current lr 1.000e-03
# __________________
# val_accuracy 0.8234333333333334
# val_ce_loss 0.5716381988154517
# __________________
# models/model_epoch120.dms
# loss 0.26
# current lr 1.000e-03
# __________________
# val_accuracy 0.8247666666666666
# val_ce_loss 0.5678112664911482
# __________________
# models/model_epoch121.dms
# loss 0.261
# current lr 1.000e-03
# __________________
# val_accuracy 0.8243666666666667
# val_ce_loss 0.5690244621541765
# __________________
# models/model_epoch122.dms
# loss 0.257
# current lr 1.000e-03
# __________________
# val_accuracy 0.8251
# val_ce_loss 0.5648650989002652
# __________________
# models/model_epoch123.dms
# loss 0.255
# current lr 1.000e-03
# __________________
# val_accuracy 0.8241666666666667
# val_ce_loss 0.5691948150634766
# __________________
# models/model_epoch124.dms
# loss 0.255
# current lr 1.000e-03
# __________________
# val_accuracy 0.8232444444444444
# val_ce_loss 0.5761944803767735
# __________________
# models/model_epoch125.dms
# loss 0.255
# current lr 1.000e-03
# __________________
# val_accuracy 0.8223333333333334
# val_ce_loss 0.5836112357192569
# __________________
# models/model_epoch126.dms
# loss 0.253
# current lr 1.000e-03
# __________________
# val_accuracy 0.8228777777777778
# val_ce_loss 0.5753614173836178
# __________________
# models/model_epoch127.dms
# loss 0.252
# current lr 1.000e-03
# __________________
# val_accuracy 0.8227222222222222
# val_ce_loss 0.5822431335899565
# __________________
# models/model_epoch128.dms
# loss 0.252
# current lr 1.000e-03
# __________________
# val_accuracy 0.8238666666666666
# val_ce_loss 0.5833007300164964
# __________________
# models/model_epoch129.dms
# loss 0.251
# current lr 1.000e-03
# __________________
# val_accuracy 0.8231666666666667
# val_ce_loss 0.5887892629199558
# __________________
# models/model_epoch130.dms
# loss 0.247
# current lr 1.000e-03
# __________________
# val_accuracy 0.8223111111111111
# val_ce_loss 0.5841280855178833
# __________________
# models/model_epoch131.dms
# loss 0.249
# current lr 1.000e-03
# __________________
# val_accuracy 0.8216777777777777
# val_ce_loss 0.584462783522076
# __________________
# models/model_epoch132.dms
# loss 0.246
# current lr 1.000e-03
# __________________
# val_accuracy 0.8225222222222223
# val_ce_loss 0.5934656730863783
# __________________
# models/model_epoch133.dms
# loss 0.246
# current lr 1.000e-03
# __________________
# val_accuracy 0.8218888888888889
# val_ce_loss 0.5963350487497118
# __________________
# models/model_epoch134.dms
# loss 0.242
# current lr 1.000e-03
# __________________
# val_accuracy 0.8226111111111111
# val_ce_loss 0.5948176203833686
# __________________
# models/model_epoch135.dms
# loss 0.242
# current lr 1.000e-03
# __________________
# val_accuracy 0.8220222222222222
# val_ce_loss 0.5987881992525524
# __________________
# models/model_epoch136.dms
# loss 0.244
# current lr 1.000e-03
# __________________
# val_accuracy 0.8224666666666667
# val_ce_loss 0.6022599948512183
# __________________
# models/model_epoch137.dms
# loss 0.242
# current lr 1.000e-03
# __________________
# val_accuracy 0.8216333333333333
# val_ce_loss 0.6012418781598409
# __________________
# models/model_epoch138.dms
# loss 0.24
# current lr 1.000e-03
# __________________
# val_accuracy 0.8217777777777778
# val_ce_loss 0.6059003352801005
# __________________
# models/model_epoch139.dms
# loss 0.24
# current lr 1.000e-03
# __________________
# val_accuracy 0.8212666666666667
# val_ce_loss 0.6056502754847208
# __________________
# models/model_epoch140.dms
# loss 0.24
# current lr 1.000e-03
# __________________
# val_accuracy 0.8222111111111111
# val_ce_loss 0.5990030777083503
# __________________
# models/model_epoch141.dms
# loss 0.24
# current lr 1.000e-03
# __________________
# val_accuracy 0.8215111111111111
# val_ce_loss 0.6053176055484348
# __________________
# models/model_epoch142.dms
# loss 0.238
# current lr 1.000e-03
# __________________
# val_accuracy 0.8219666666666666
# val_ce_loss 0.6057154412534502
# __________________
# models/model_epoch143.dms
# loss 0.237
# current lr 1.000e-03
# __________________
# val_accuracy 0.8210444444444445
# val_ce_loss 0.6054385744147831
# __________________
# models/model_epoch144.dms
# loss 0.235
# current lr 1.000e-03
# __________________
# val_accuracy 0.8203777777777778
# val_ce_loss 0.6090505110634697
# __________________
# models/model_epoch145.dms
# loss 0.237
# current lr 1.000e-03
# __________________
# val_accuracy 0.8206111111111111
# val_ce_loss 0.6136831690841251
# __________________
# models/model_epoch146.dms
# loss 0.234
# current lr 1.000e-03
# __________________
# val_accuracy 0.8210888888888889
# val_ce_loss 0.6138602248509725
# __________________
# models/model_epoch147.dms
# loss 0.234
# current lr 1.000e-03
# __________________
# val_accuracy 0.8199222222222222
# val_ce_loss 0.6216362126085493
# __________________
# models/model_epoch148.dms
# loss 0.235
# current lr 1.000e-03
# __________________
# val_accuracy 0.8201444444444445
# val_ce_loss 0.6197347652753195
# __________________
# models/model_epoch149.dms
# loss 0.231
# current lr 1.000e-03
# __________________
# val_accuracy 0.8216777777777777
# val_ce_loss 0.6144878950648838
# __________________
# choosen epoch: 115 , score: 0.8259333333333333
# best epoch: 115 , score: 0.8259333333333333
# -----------------
# resnet20_classic.pt
# test_accuracy 0.8219111111111111
# test_ce_loss 0.5648095791843203
# __________________
# val_accuracy 0.8259333333333333
# val_ce_loss 0.5549910778734419
# __________________
# train_accuracy 0.9138666666666667
# train_ce_loss 0.2434871630138821
# __________________
# ----------------
# models/model_epoch0.dms
# loss 1.81
# current lr 1.000e-01
# __________________
# val_accuracy 0.41381111111111113
# val_ce_loss 1.606191956308153
# __________________
# models/model_epoch1.dms
# loss 1.4
# current lr 1.000e-01
# __________________
# val_accuracy 0.536
# val_ce_loss 1.2671253500832451
# __________________
# models/model_epoch2.dms
# loss 1.21
# current lr 1.000e-01
# __________________
# val_accuracy 0.5695777777777777
# val_ce_loss 1.2046221297581992
# __________________
# models/model_epoch3.dms
# loss 1.1
# current lr 1.000e-01
# __________________
# val_accuracy 0.5925222222222222
# val_ce_loss 1.1274812199062771
# __________________
# models/model_epoch4.dms
# loss 1.02
# current lr 1.000e-01
# __________________
# val_accuracy 0.6226
# val_ce_loss 1.07890970448388
# __________________
# models/model_epoch5.dms
# loss 0.972
# current lr 1.000e-01
# __________________
# val_accuracy 0.6521444444444444
# val_ce_loss 0.9894514433966742
# __________________
# models/model_epoch6.dms
# loss 0.931
# current lr 1.000e-01
# __________________
# val_accuracy 0.6397555555555555
# val_ce_loss 1.0214864322026571
# __________________
# models/model_epoch7.dms
# loss 0.903
# current lr 1.000e-01
# __________________
# val_accuracy 0.6601444444444444
# val_ce_loss 0.9715923463079664
# __________________
# models/model_epoch8.dms
# loss 0.88
# current lr 1.000e-01
# __________________
# val_accuracy 0.6809333333333333
# val_ce_loss 0.8869259210904439
# __________________
# models/model_epoch9.dms
# loss 0.856
# current lr 1.000e-01
# __________________
# val_accuracy 0.6683333333333333
# val_ce_loss 0.9895530478371514
# __________________
# models/model_epoch10.dms
# loss 0.839
# current lr 1.000e-01
# __________________
# val_accuracy 0.6852
# val_ce_loss 0.9138617021666633
# __________________
# models/model_epoch11.dms
# loss 0.819
# current lr 1.000e-01
# __________________
# val_accuracy 0.6816444444444445
# val_ce_loss 0.8984253541522556
# __________________
# models/model_epoch12.dms
# loss 0.808
# current lr 1.000e-01
# __________________
# val_accuracy 0.7049444444444445
# val_ce_loss 0.8317722339206272
# __________________
# models/model_epoch13.dms
# loss 0.796
# current lr 1.000e-01
# __________________
# val_accuracy 0.6690555555555555
# val_ce_loss 0.9854491232977973
# __________________
# models/model_epoch14.dms
# loss 0.788
# current lr 1.000e-01
# __________________
# val_accuracy 0.7105666666666667
# val_ce_loss 0.8238247349103291
# __________________
# models/model_epoch15.dms
# loss 0.773
# current lr 1.000e-01
# __________________
# val_accuracy 0.6856555555555556
# val_ce_loss 0.9349824036916097
# __________________
# models/model_epoch16.dms
# loss 0.765
# current lr 1.000e-01
# __________________
# val_accuracy 0.7154111111111111
# val_ce_loss 0.8045598302523295
# __________________
# models/model_epoch17.dms
# loss 0.76
# current lr 1.000e-01
# __________________
# val_accuracy 0.7111555555555555
# val_ce_loss 0.8296266082233853
# __________________
# models/model_epoch18.dms
# loss 0.748
# current lr 1.000e-01
# __________________
# val_accuracy 0.7213333333333334
# val_ce_loss 0.806725489282608
# __________________
# models/model_epoch19.dms
# loss 0.745
# current lr 1.000e-01
# __________________
# val_accuracy 0.7052555555555555
# val_ce_loss 0.8485739510536194
# __________________
# models/model_epoch20.dms
# loss 0.739
# current lr 1.000e-01
# __________________
# val_accuracy 0.6998333333333333
# val_ce_loss 0.8458243179215326
# __________________
# models/model_epoch21.dms
# loss 0.735
# current lr 1.000e-01
# __________________
# val_accuracy 0.7341777777777778
# val_ce_loss 0.7499883312331306
# __________________
# models/model_epoch22.dms
# loss 0.728
# current lr 1.000e-01
# __________________
# val_accuracy 0.7352777777777778
# val_ce_loss 0.756385399225023
# __________________
# models/model_epoch23.dms
# loss 0.722
# current lr 1.000e-01
# __________________
# val_accuracy 0.7253777777777778
# val_ce_loss 0.7856372782601251
# __________________
# models/model_epoch24.dms
# loss 0.717
# current lr 1.000e-01
# __________________
# val_accuracy 0.7423444444444445
# val_ce_loss 0.7360916639751858
# __________________
# models/model_epoch25.dms
# loss 0.716
# current lr 1.000e-01
# __________________
# val_accuracy 0.7093555555555555
# val_ce_loss 0.8529463138262431
# __________________
# models/model_epoch26.dms
# loss 0.708
# current lr 1.000e-01
# __________________
# val_accuracy 0.7119222222222222
# val_ce_loss 0.8200514181878832
# __________________
# models/model_epoch27.dms
# loss 0.706
# current lr 1.000e-01
# __________________
# val_accuracy 0.7014777777777778
# val_ce_loss 0.8815804265975952
# __________________
# models/model_epoch28.dms
# loss 0.702
# current lr 1.000e-01
# __________________
# val_accuracy 0.6855333333333333
# val_ce_loss 0.9073262765036689
# __________________
# models/model_epoch29.dms
# loss 0.7
# current lr 1.000e-01
# __________________
# val_accuracy 0.7267888888888889
# val_ce_loss 0.7756601837793986
# __________________
# models/model_epoch30.dms
# loss 0.694
# current lr 1.000e-01
# __________________
# val_accuracy 0.7262777777777778
# val_ce_loss 0.7911464897473653
# __________________
# models/model_epoch31.dms
# loss 0.691
# current lr 1.000e-01
# __________________
# val_accuracy 0.7155111111111111
# val_ce_loss 0.8222749824100071
# __________________
# models/model_epoch32.dms
# loss 0.684
# current lr 1.000e-01
# __________________
# val_accuracy 0.6835
# val_ce_loss 0.9555823501798841
# __________________
# models/model_epoch33.dms
# loss 0.687
# current lr 1.000e-01
# __________________
# val_accuracy 0.7103111111111111
# val_ce_loss 0.8426820397906833
# __________________
# models/model_epoch34.dms
# loss 0.682
# current lr 1.000e-01
# __________________
# val_accuracy 0.7315333333333334
# val_ce_loss 0.7726305449591743
# __________________
# models/model_epoch35.dms
# loss 0.686
# current lr 1.000e-01
# __________________
# val_accuracy 0.7402555555555556
# val_ce_loss 0.7406455268383026
# __________________
# models/model_epoch36.dms
# loss 0.681
# current lr 1.000e-01
# __________________
# val_accuracy 0.7352111111111111
# val_ce_loss 0.7586951938735115
# __________________
# models/model_epoch37.dms
# loss 0.681
# current lr 1.000e-01
# __________________
# val_accuracy 0.7336
# val_ce_loss 0.7722037963231405
# __________________
# models/model_epoch38.dms
# loss 0.671
# current lr 1.000e-01
# __________________
# val_accuracy 0.7253333333333334
# val_ce_loss 0.7846122677909003
# __________________
# models/model_epoch39.dms
# loss 0.675
# current lr 1.000e-01
# __________________
# val_accuracy 0.7204111111111111
# val_ce_loss 0.8304511903974745
# __________________
# models/model_epoch40.dms
# loss 0.674
# current lr 1.000e-01
# __________________
# val_accuracy 0.7389111111111111
# val_ce_loss 0.7430464920891656
# __________________
# models/model_epoch41.dms
# loss 0.671
# current lr 1.000e-01
# __________________
# val_accuracy 0.7489222222222223
# val_ce_loss 0.7331778978983561
# __________________
# models/model_epoch42.dms
# loss 0.666
# current lr 1.000e-01
# __________________
# val_accuracy 0.6787444444444445
# val_ce_loss 1.0107040835486518
# __________________
# models/model_epoch43.dms
# loss 0.668
# current lr 1.000e-01
# __________________
# val_accuracy 0.7455444444444445
# val_ce_loss 0.7211173214912414
# __________________
# models/model_epoch44.dms
# loss 0.668
# current lr 1.000e-01
# __________________
# val_accuracy 0.7627666666666667
# val_ce_loss 0.6779099917729695
# __________________
# models/model_epoch45.dms
# loss 0.664
# current lr 1.000e-01
# __________________
# val_accuracy 0.7012222222222222
# val_ce_loss 0.864183997048272
# __________________
# models/model_epoch46.dms
# loss 0.662
# current lr 1.000e-01
# __________________
# val_accuracy 0.7438666666666667
# val_ce_loss 0.7353399407598707
# __________________
# models/model_epoch47.dms
# loss 0.663
# current lr 1.000e-01
# __________________
# val_accuracy 0.7248444444444444
# val_ce_loss 0.7871792500072056
# __________________
# models/model_epoch48.dms
# loss 0.659
# current lr 1.000e-01
# __________________
# val_accuracy 0.7214888888888888
# val_ce_loss 0.852481277455224
# __________________
# models/model_epoch49.dms
# loss 0.659
# current lr 1.000e-01
# __________________
# val_accuracy 0.7145333333333334
# val_ce_loss 0.8070667030970256
# __________________
# models/model_epoch50.dms
# loss 0.661
# current lr 1.000e-01
# __________________
# val_accuracy 0.7430777777777777
# val_ce_loss 0.7504986899905735
# __________________
# models/model_epoch51.dms
# loss 0.652
# current lr 1.000e-01
# __________________
# val_accuracy 0.7221888888888889
# val_ce_loss 0.831129098256429
# __________________
# models/model_epoch52.dms
# loss 0.659
# current lr 1.000e-01
# __________________
# val_accuracy 0.7075555555555556
# val_ce_loss 0.8498526226997376
# __________________
# models/model_epoch53.dms
# loss 0.658
# current lr 1.000e-01
# __________________
# val_accuracy 0.7408222222222223
# val_ce_loss 0.7589483050876193
# __________________
# models/model_epoch54.dms
# loss 0.655
# current lr 1.000e-01
# __________________
# val_accuracy 0.7218444444444444
# val_ce_loss 0.8411494323094686
# __________________
# models/model_epoch55.dms
# loss 0.655
# current lr 1.000e-01
# __________________
# val_accuracy 0.7002888888888888
# val_ce_loss 0.8776955216301812
# __________________
# models/model_epoch56.dms
# loss 0.653
# current lr 1.000e-01
# __________________
# val_accuracy 0.6562444444444444
# val_ce_loss 1.0479851532406277
# __________________
# models/model_epoch57.dms
# loss 0.487
# current lr 1.000e-02
# __________________
# val_accuracy 0.8136555555555556
# val_ce_loss 0.536320665412479
# __________________
# models/model_epoch58.dms
# loss 0.443
# current lr 1.000e-02
# __________________
# val_accuracy 0.8182444444444444
# val_ce_loss 0.5238800765885248
# __________________
# models/model_epoch59.dms
# loss 0.423
# current lr 1.000e-02
# __________________
# val_accuracy 0.8193888888888889
# val_ce_loss 0.5225377214113871
# __________________
# models/model_epoch60.dms
# loss 0.409
# current lr 1.000e-02
# __________________
# val_accuracy 0.8229666666666666
# val_ce_loss 0.517890749279658
# __________________
# models/model_epoch61.dms
# loss 0.395
# current lr 1.000e-02
# __________________
# val_accuracy 0.8232777777777778
# val_ce_loss 0.5226740867031945
# __________________
# models/model_epoch62.dms
# loss 0.388
# current lr 1.000e-02
# __________________
# val_accuracy 0.8228666666666666
# val_ce_loss 0.5244844691117605
# __________________
# models/model_epoch63.dms
# loss 0.38
# current lr 1.000e-02
# __________________
# val_accuracy 0.8243666666666667
# val_ce_loss 0.5168007419374254
# __________________
# models/model_epoch64.dms
# loss 0.373
# current lr 1.000e-02
# __________________
# val_accuracy 0.8235555555555556
# val_ce_loss 0.5306255553351509
# __________________
# models/model_epoch65.dms
# loss 0.364
# current lr 1.000e-02
# __________________
# val_accuracy 0.8249111111111112
# val_ce_loss 0.522605355032285
# __________________
# models/model_epoch66.dms
# loss 0.359
# current lr 1.000e-02
# __________________
# val_accuracy 0.8231
# val_ce_loss 0.5352758699099223
# __________________
# models/model_epoch67.dms
# loss 0.353
# current lr 1.000e-02
# __________________
# val_accuracy 0.8233
# val_ce_loss 0.5259215002907647
# __________________
# models/model_epoch68.dms
# loss 0.351
# current lr 1.000e-02
# __________________
# val_accuracy 0.8228777777777778
# val_ce_loss 0.5340549277093676
# __________________
# models/model_epoch69.dms
# loss 0.346
# current lr 1.000e-02
# __________________
# val_accuracy 0.8225333333333333
# val_ce_loss 0.539247941939036
# __________________
# models/model_epoch70.dms
# loss 0.34
# current lr 1.000e-02
# __________________
# val_accuracy 0.8190111111111111
# val_ce_loss 0.5616919258647495
# __________________
# models/model_epoch71.dms
# loss 0.339
# current lr 1.000e-02
# __________________
# val_accuracy 0.8216888888888889
# val_ce_loss 0.5465265293121337
# __________________
# models/model_epoch72.dms
# loss 0.334
# current lr 1.000e-02
# __________________
# val_accuracy 0.8193
# val_ce_loss 0.5502903615951538
# __________________
# models/model_epoch73.dms
# loss 0.331
# current lr 1.000e-02
# __________________
# val_accuracy 0.8158
# val_ce_loss 0.5735609461890326
# __________________
# models/model_epoch74.dms
# loss 0.329
# current lr 1.000e-02
# __________________
# val_accuracy 0.8212
# val_ce_loss 0.5518902234130435
# __________________
# models/model_epoch75.dms
# loss 0.326
# current lr 1.000e-02
# __________________
# val_accuracy 0.8157666666666666
# val_ce_loss 0.5793412528779771
# __________________
# models/model_epoch76.dms
# loss 0.323
# current lr 1.000e-02
# __________________
# val_accuracy 0.8192222222222222
# val_ce_loss 0.5636790179835426
# __________________
# models/model_epoch77.dms
# loss 0.321
# current lr 1.000e-02
# __________________
# val_accuracy 0.8152222222222222
# val_ce_loss 0.5855898847791884
# __________________
# models/model_epoch78.dms
# loss 0.322
# current lr 1.000e-02
# __________________
# val_accuracy 0.8141777777777778
# val_ce_loss 0.5858618465211657
# __________________
# models/model_epoch79.dms
# loss 0.319
# current lr 1.000e-02
# __________________
# val_accuracy 0.8154333333333333
# val_ce_loss 0.5834013955116272
# __________________
# models/model_epoch80.dms
# loss 0.317
# current lr 1.000e-02
# __________________
# val_accuracy 0.8176777777777777
# val_ce_loss 0.5580925566461351
# __________________
# models/model_epoch81.dms
# loss 0.316
# current lr 1.000e-02
# __________________
# val_accuracy 0.8174333333333333
# val_ce_loss 0.582383977733718
# __________________
# models/model_epoch82.dms
# loss 0.316
# current lr 1.000e-02
# __________________
# val_accuracy 0.8170444444444445
# val_ce_loss 0.5837168886078729
# __________________
# models/model_epoch83.dms
# loss 0.313
# current lr 1.000e-02
# __________________
# val_accuracy 0.8137777777777778
# val_ce_loss 0.5972741378095415
# __________________
# models/model_epoch84.dms
# loss 0.312
# current lr 1.000e-02
# __________________
# val_accuracy 0.8173777777777778
# val_ce_loss 0.5885179659631518
# __________________
# models/model_epoch85.dms
# loss 0.313
# current lr 1.000e-02
# __________________
# val_accuracy 0.8179888888888889
# val_ce_loss 0.5735633648130629
# __________________
# models/model_epoch86.dms
# loss 0.311
# current lr 1.000e-02
# __________________
# val_accuracy 0.8190777777777778
# val_ce_loss 0.5823142123858134
# __________________
# models/model_epoch87.dms
# loss 0.307
# current lr 1.000e-02
# __________________
# val_accuracy 0.8084111111111111
# val_ce_loss 0.6061486519336701
# __________________
# models/model_epoch88.dms
# loss 0.309
# current lr 1.000e-02
# __________________
# val_accuracy 0.8150888888888889
# val_ce_loss 0.594676549688975
# __________________
# models/model_epoch89.dms
# loss 0.309
# current lr 1.000e-02
# __________________
# val_accuracy 0.8075666666666667
# val_ce_loss 0.62970363234414
# __________________
# models/model_epoch90.dms
# loss 0.308
# current lr 1.000e-02
# __________________
# val_accuracy 0.8192
# val_ce_loss 0.5915342015160454
# __________________
# models/model_epoch91.dms
# loss 0.307
# current lr 1.000e-02
# __________________
# val_accuracy 0.8134222222222223
# val_ce_loss 0.5987754442744785
# __________________
# models/model_epoch92.dms
# loss 0.307
# current lr 1.000e-02
# __________________
# val_accuracy 0.8163
# val_ce_loss 0.5981256784333123
# __________________
# models/model_epoch93.dms
# loss 0.307
# current lr 1.000e-02
# __________________
# val_accuracy 0.8122777777777778
# val_ce_loss 0.610007109398312
# __________________
# models/model_epoch94.dms
# loss 0.305
# current lr 1.000e-02
# __________________
# val_accuracy 0.8118444444444445
# val_ce_loss 0.6135575867229038
# __________________
# models/model_epoch95.dms
# loss 0.302
# current lr 1.000e-02
# __________________
# val_accuracy 0.817
# val_ce_loss 0.5899447959476047
# __________________
# models/model_epoch96.dms
# loss 0.307
# current lr 1.000e-02
# __________________
# val_accuracy 0.8120777777777778
# val_ce_loss 0.6217878619829814
# __________________
# models/model_epoch97.dms
# loss 0.307
# current lr 1.000e-02
# __________________
# val_accuracy 0.8100666666666667
# val_ce_loss 0.6222401802804735
# __________________
# models/model_epoch98.dms
# loss 0.301
# current lr 1.000e-02
# __________________
# val_accuracy 0.8119444444444445
# val_ce_loss 0.602029399342007
# __________________
# models/model_epoch99.dms
# loss 0.302
# current lr 1.000e-02
# __________________
# val_accuracy 0.8005222222222222
# val_ce_loss 0.6634843804253472
# __________________
# models/model_epoch100.dms
# loss 0.299
# current lr 1.000e-02
# __________________
# val_accuracy 0.8090222222222222
# val_ce_loss 0.6355492649502225
# __________________
# models/model_epoch101.dms
# loss 0.299
# current lr 1.000e-02
# __________________
# val_accuracy 0.8099222222222222
# val_ce_loss 0.6317456392923991
# __________________
# models/model_epoch102.dms
# loss 0.304
# current lr 1.000e-02
# __________________
# val_accuracy 0.8111666666666667
# val_ce_loss 0.6236348946465387
# __________________
# models/model_epoch103.dms
# loss 0.299
# current lr 1.000e-02
# __________________
# val_accuracy 0.8117888888888889
# val_ce_loss 0.6179077629301283
# __________________
# models/model_epoch104.dms
# loss 0.298
# current lr 1.000e-02
# __________________
# val_accuracy 0.8144111111111111
# val_ce_loss 0.6087758066601223
# __________________
# models/model_epoch105.dms
# loss 0.298
# current lr 1.000e-02
# __________________
# val_accuracy 0.8162666666666667
# val_ce_loss 0.6164448725912306
# __________________
# models/model_epoch106.dms
# loss 0.297
# current lr 1.000e-02
# __________________
# val_accuracy 0.8095
# val_ce_loss 0.626144879828559
# __________________
# models/model_epoch107.dms
# loss 0.298
# current lr 1.000e-02
# __________________
# val_accuracy 0.8063666666666667
# val_ce_loss 0.6564830933994718
# __________________
# models/model_epoch108.dms
# loss 0.297
# current lr 1.000e-02
# __________________
# val_accuracy 0.8090666666666667
# val_ce_loss 0.6325836849000719
# __________________
# models/model_epoch109.dms
# loss 0.296
# current lr 1.000e-02
# __________________
# val_accuracy 0.8138
# val_ce_loss 0.6012654767566257
# __________________
# models/model_epoch110.dms
# loss 0.295
# current lr 1.000e-02
# __________________
# val_accuracy 0.8101555555555555
# val_ce_loss 0.6438507866541544
# __________________
# models/model_epoch111.dms
# loss 0.296
# current lr 1.000e-02
# __________________
# val_accuracy 0.8128
# val_ce_loss 0.6136009902848137
# __________________
# models/model_epoch112.dms
# loss 0.293
# current lr 1.000e-02
# __________________
# val_accuracy 0.8114777777777777
# val_ce_loss 0.6085641614807976
# __________________
# models/model_epoch113.dms
# loss 0.292
# current lr 1.000e-02
# __________________
# val_accuracy 0.8054444444444444
# val_ce_loss 0.6460687094052633
# __________________
# models/model_epoch114.dms
# loss 0.292
# current lr 1.000e-02
# __________________
# val_accuracy 0.8078444444444445
# val_ce_loss 0.6442526233620114
# __________________
# models/model_epoch115.dms
# loss 0.289
# current lr 1.000e-02
# __________________
# val_accuracy 0.8014333333333333
# val_ce_loss 0.6738827398512098
# __________________
# models/model_epoch116.dms
# loss 0.29
# current lr 1.000e-02
# __________________
# val_accuracy 0.8092666666666667
# val_ce_loss 0.630230472861396
# __________________
# models/model_epoch117.dms
# loss 0.292
# current lr 1.000e-02
# __________________
# val_accuracy 0.8051333333333334
# val_ce_loss 0.6646645053492652
# __________________
# models/model_epoch118.dms
# loss 0.293
# current lr 1.000e-02
# __________________
# val_accuracy 0.8105666666666667
# val_ce_loss 0.6265999184714424
# __________________
# models/model_epoch119.dms
# loss 0.289
# current lr 1.000e-02
# __________________
# val_accuracy 0.8034222222222223
# val_ce_loss 0.6477226345698038
# __________________
# models/model_epoch120.dms
# loss 0.289
# current lr 1.000e-02
# __________________
# val_accuracy 0.8057666666666666
# val_ce_loss 0.6373124891599019
# __________________
# models/model_epoch121.dms
# loss 0.217
# current lr 1.000e-03
# __________________
# val_accuracy 0.8298888888888889
# val_ce_loss 0.5632687267833286
# __________________
# models/model_epoch122.dms
# loss 0.188
# current lr 1.000e-03
# __________________
# val_accuracy 0.8304222222222222
# val_ce_loss 0.5784738806830512
# __________________
# models/model_epoch123.dms
# loss 0.179
# current lr 1.000e-03
# __________________
# val_accuracy 0.8298888888888889
# val_ce_loss 0.5908323022577497
# __________________
# models/model_epoch124.dms
# loss 0.171
# current lr 1.000e-03
# __________________
# val_accuracy 0.8303777777777778
# val_ce_loss 0.5992713288784027
# __________________
# models/model_epoch125.dms
# loss 0.162
# current lr 1.000e-03
# __________________
# val_accuracy 0.8316444444444444
# val_ce_loss 0.605858005115721
# __________________
# models/model_epoch126.dms
# loss 0.158
# current lr 1.000e-03
# __________________
# val_accuracy 0.8301555555555555
# val_ce_loss 0.6079382432036929
# __________________
# models/model_epoch127.dms
# loss 0.155
# current lr 1.000e-03
# __________________
# val_accuracy 0.8304444444444444
# val_ce_loss 0.6096033807648553
# __________________
# models/model_epoch128.dms
# loss 0.151
# current lr 1.000e-03
# __________________
# val_accuracy 0.8303222222222222
# val_ce_loss 0.6173523958418105
# __________________
# models/model_epoch129.dms
# loss 0.148
# current lr 1.000e-03
# __________________
# val_accuracy 0.8306111111111111
# val_ce_loss 0.6225854498969184
# __________________
# models/model_epoch130.dms
# loss 0.146
# current lr 1.000e-03
# __________________
# val_accuracy 0.8304222222222222
# val_ce_loss 0.6316121581660377
# __________________
# models/model_epoch131.dms
# loss 0.143
# current lr 1.000e-03
# __________________
# val_accuracy 0.8299888888888889
# val_ce_loss 0.628234729968177
# __________________
# models/model_epoch132.dms
# loss 0.142
# current lr 1.000e-03
# __________________
# val_accuracy 0.8310111111111111
# val_ce_loss 0.637226251188914
# __________________
# models/model_epoch133.dms
# loss 0.139
# current lr 1.000e-03
# __________________
# val_accuracy 0.8303
# val_ce_loss 0.6414034109486474
# __________________
# models/model_epoch134.dms
# loss 0.136
# current lr 1.000e-03
# __________________
# val_accuracy 0.8301111111111111
# val_ce_loss 0.6472712313863966
# __________________
# models/model_epoch135.dms
# loss 0.137
# current lr 1.000e-03
# __________________
# val_accuracy 0.8302333333333334
# val_ce_loss 0.6454101350890266
# __________________
# models/model_epoch136.dms
# loss 0.133
# current lr 1.000e-03
# __________________
# val_accuracy 0.8288666666666666
# val_ce_loss 0.664676172235277
# __________________
# models/model_epoch137.dms
# loss 0.131
# current lr 1.000e-03
# __________________
# val_accuracy 0.8293666666666667
# val_ce_loss 0.663599447160297
# __________________
# models/model_epoch138.dms
# loss 0.129
# current lr 1.000e-03
# __________________
# val_accuracy 0.8288555555555556
# val_ce_loss 0.6642612163649665
# __________________
# models/model_epoch139.dms
# loss 0.127
# current lr 1.000e-03
# __________________
# val_accuracy 0.8274888888888889
# val_ce_loss 0.6756515798515743
# __________________
# models/model_epoch140.dms
# loss 0.125
# current lr 1.000e-03
# __________________
# val_accuracy 0.8284444444444444
# val_ce_loss 0.6786580159717136
# __________________
# models/model_epoch141.dms
# loss 0.125
# current lr 1.000e-03
# __________________
# val_accuracy 0.8292555555555555
# val_ce_loss 0.6732674385335711
# __________________
# models/model_epoch142.dms
# loss 0.122
# current lr 1.000e-03
# __________________
# val_accuracy 0.8291666666666667
# val_ce_loss 0.6800338418112861
# __________________
# models/model_epoch143.dms
# loss 0.12
# current lr 1.000e-03
# __________________
# val_accuracy 0.8289555555555556
# val_ce_loss 0.6823497952408261
# __________________
# models/model_epoch144.dms
# loss 0.12
# current lr 1.000e-03
# __________________
# val_accuracy 0.8292
# val_ce_loss 0.6944108888785044
# __________________
# models/model_epoch145.dms
# loss 0.118
# current lr 1.000e-03
# __________________
# val_accuracy 0.8276111111111111
# val_ce_loss 0.7039515364170075
# __________________
# models/model_epoch146.dms
# loss 0.12
# current lr 1.000e-03
# __________________
# val_accuracy 0.8285555555555556
# val_ce_loss 0.7031850302113427
# __________________
# models/model_epoch147.dms
# loss 0.118
# current lr 1.000e-03
# __________________
# val_accuracy 0.8289
# val_ce_loss 0.7008592888037364
# __________________
# models/model_epoch148.dms
# loss 0.116
# current lr 1.000e-03
# __________________
# val_accuracy 0.8277777777777777
# val_ce_loss 0.7066970842573378
# __________________
# models/model_epoch149.dms
# loss 0.115
# current lr 1.000e-03
# __________________
# val_accuracy 0.8284
# val_ce_loss 0.7072173418680827
# __________________
# choosen epoch: 125 , score: 0.8316444444444444
# best epoch: 125 , score: 0.8316444444444444
# -----------------
# resnet32_classic.pt
# test_accuracy 0.8278333333333333
# test_ce_loss 0.6186350774791506
# __________________
# val_accuracy 0.8316444444444444
# val_ce_loss 0.6058580021487342
# __________________
# train_accuracy 0.9529555555555556
# train_ce_loss 0.13679252112176682
# __________________
# ----------------

# %% [markdown]
# Saving logs and remove extra files for kaggle kernel

# %%
# !tar -czf logs.tar.gz logs

# %%
# !rm -rf test train valid resnet.py models logs
