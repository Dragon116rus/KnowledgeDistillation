# %% [markdown]
# Downloanding third-party code for resnet model

# %%
# !wget https://raw.githubusercontent.com/akamaster/pytorch_resnet_cifar10/d1872999394aa0c234e8d855e3c853eb061f7c06/resnet.py
# Out:
# --2020-02-19 08:34:29--  https://raw.githubusercontent.com/akamaster/pytorch_resnet_cifar10/d1872999394aa0c234e8d855e3c853eb061f7c06/resnet.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5001 (4.9K) [text/plain]
# Saving to: ‘resnet.py’
#
# resnet.py           100%[===================>]   4.88K  --.-KB/s    in 0s
#
# 2020-02-19 08:34:30 (106 MB/s) - ‘resnet.py’ saved [5001/5001]

# %% [markdown]
# Downloading/uploading with google drive

# %%
# autorize in google dirve
from google.colab import drive
drive.mount('/content/gdrive')

# download model from google drive
def download_model(source_name, saving_name):
  drive.mount('/content/gdrive')
  # !cp "gdrive/My Drive/Colab Notebooks/Study/theasis/cifar100_models/{source_name}" {saving_name}

# upload model to google drive
def upload_model(source_name, saving_name):
  drive.mount('/content/gdrive')
  # !cp {source_name} "gdrive/My Drive/Colab Notebooks/Study/theasis/cifar100_models/{saving_name}" 

def upload_logs():
  drive.mount('/content/gdrive')
  # !cp -r logs "gdrive/My Drive/Colab Notebooks/Study/theasis/"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Libs importing

# %%
import gc
import os
import datetime

import numpy as np
np.random.seed(42)

import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils as utils
from torch.utils.data import Subset, ConcatDataset, DataLoader

from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import accuracy_score

from resnet import BasicBlock, _weights_init

# %% [markdown]
# Models declaration

# %%
class ResNetModified(nn.Module):
    def __init__(self, block, num_blocks, input_channels, num_classes=10):
        super(ResNetModified, self).__init__()
        self.in_planes = 16

        self.conv1 = nn.Conv2d(input_channels, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        self.layer1 = self._make_layer(block, 16, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 32, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 64, num_blocks[2], stride=2)
        self.linear = nn.Linear(64, num_classes)

        self.apply(_weights_init)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion

        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
def resnet7():return ResNetModified(BasicBlock, [1, 1, 1], 3, 100)
def resnet20():return ResNetModified(BasicBlock, [3, 3, 3], 3, 100)
def resnet32():return ResNetModified(BasicBlock, [5, 5, 5], 3, 100)

# %% [markdown]
# Declaration of utils

# %%
class AverageMeter:
  """Class for computing average values
  """    
  def __init__(self):
    """Init class
    """      
    self.sum_ = 0
    self.count = 0
  
  def update(self, val, count=1):
    """Add new value to track
    
    Arguments:
        val {float} -- new value
    
    Keyword Arguments:
        count {int} -- weigth of val (default: {1})
    """      
    self.sum_ += val
    self.count += count

  def average(self):
    """return average value for given values
    """      
    return self.sum_ / self.count

# %%
from tensorboard.plugins.hparams import api as hp
class TensorBoardLogger:
    """Class for logging into TensorBoard
    """    
    def __init__(self, log_dir, dataset, net, experiment_name):
        """Init logger
        
        Arguments:
            log_dir {string} -- log dir
            dataset {string} -- name of dataset
            experiment_name {string} -- name of experiment
        """        
        current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
        log_dir_full = os.path.join(log_dir, dataset, net, experiment_name, current_time)
        self.writer = tf.summary.create_file_writer(log_dir_full)
        self.step_ = 0
        
    def log_scalar(self, tag, value, step=None, description=None):
        """Log scalar
        
        Arguments:
            tag {string} -- name of variable to log
            value {float} -- value of variable
        
        Keyword Arguments:
            step {int} -- current epoch number (default: {None})
            description {string} -- [description] (default: {None})
        """        
        if step is None:
            step = self.step_
        with self.writer.as_default():
            tf.summary.scalar(tag, value, step=step, description=description)
            
    def step(self):
        """Increase epoch number by 1
        """        
        self.step_+=1

    def log_hparams(self, hparams):
        """log hparams
        
        Arguments:
            hparams {dict} -- dict to log
        """      
        with self.writer.as_default():
            hp.hparams(hparams)

# %% [markdown]
# Dataset declaration

# %%
batch_size = 64

dataset_name = "cifar100"

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

# augmentation and normaliztion for training
transform_train = transforms.Compose(
    [
     transforms.RandomHorizontalFlip(p=0.5),
     transforms.RandomCrop(32, 4),
     transforms.ToTensor(),
     normalize
     ])

# only normalization for testing
transform_test = transforms.Compose(
    [
     transforms.ToTensor(),
     normalize
     ])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True,
                                        download=True, transform=transform_train)
valset = torchvision.datasets.CIFAR100(root='./data', train=True,
                                        download=True, transform=transform_test)
# split trainvalset into val and train
idx = np.arange(len(trainset))
split = int(len(trainset)*0.15)
np.random.seed(42) # set seed to reproduce given set
np.random.shuffle(idx)
train_idx = idx[split:]
val_idx = idx[:split]

trainset = Subset(trainset, train_idx)
valset = Subset(valset, val_idx)


trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2,
                                          pin_memory=True, 
                                          )
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size,
                                          shuffle=True, num_workers=2,
                                          pin_memory=True, 
                                          )

testset = torchvision.datasets.CIFAR100(root='./data', train=False,
                                       download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2,
                                         pin_memory=True, )
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def imshow(img):
    img = img / 4 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0315 18:12:16.685757 139761805358912 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# check the first index, to check that trainval set splitted correctly
assert val_idx[0]==33553, "invalid val set"

# %% [markdown]
# Training functions definition

# %%
def accuracy_minibatch(outputs, labels):
  if isinstance(outputs, torch.Tensor):
    outputs = outputs.cpu().detach().numpy()
  if isinstance(labels, torch.Tensor):
    labels = labels.cpu().detach().numpy()
  
  predict_= np.argmax(outputs, axis=1)
  true_labels_= labels
  micro_acc_score = accuracy_score(predict_, true_labels_)
  return micro_acc_score

# %%
def validate(net, testloader, logger=None, compression_f=None, verbose=True, prename="val"):
  """Function for compute metrics on validation set
  
  Arguments:
      net {torch net} -- model
      testloader {DataLoader} -- set to validation
      
  Keyword Arguments:
      logger {TensorBoardLogger} -- logger (default: {None})
      compression_f {function} -- function to preprocess input (default: {None})
      verbose {bool} -- show metrics (default: {True})
      prename {string} -- prename to name of metric (default: {"val"})
  
  Returns:
      [floats] -- scores for computing metrics
  """  
  # change net to evaluation mode
  net.eval()
  ce_loss_avg = AverageMeter()
  accuracy_score_avg = AverageMeter()
  criterion = nn.CrossEntropyLoss()
  
  # evaluate dataset
  for i, data in enumerate(testloader, 0):
    inputs, labels = data
    inputs, labels = inputs.cuda(), labels.cuda()
    current_batch_size = len(labels)

    if compression_f is not None:
      inputs = compression_f(inputs)
    outputs = net(inputs)
    loss = criterion(outputs, labels).cpu().detach().numpy()
    
    micro_acc_score = accuracy_minibatch(outputs, labels)

    accuracy_score_avg.update(micro_acc_score*current_batch_size, current_batch_size)
    ce_loss_avg.update(loss.item()*current_batch_size, current_batch_size)

  accuracy = accuracy_score_avg.average()
  ce_loss = ce_loss_avg.average()
  scores = {"%s_accuracy"%prename:accuracy, "%s_ce_loss"%prename:ce_loss}
  
  # log scores
  for name, score in scores.items():
    if logger:
      logger.log_scalar(name, score)
    if verbose:
      print(name, score)
  
  if verbose:
    print("__________________")
  # change net to training mode
  net.train()
  return scores

# %%
def train_classic_approach(
    net, 
    trainloader, 
    testloader, 
    epoches=300,
    compression_f=None, 
    verbose=True, 
    return_best=True,
    logger=None,
    init_lr=0.1
    ):
  """Training using classic approach
  
  Arguments:
      net {torch model} -- model
      trainloader {DataLoader} -- train set
      testloader {DataLoader} -- test set
  
  Keyword Arguments:
      epoches {int} -- epocs to train (default: {300})
      compression_f {[type]} -- function to preprocess input (default: {None})
      verbose {bool} -- show metrics (default: {True})
      return_best {bool} -- return best model (default: {True})
      logger {TensorBoardLogger} -- logger (default: {None})
      init_lr {float} -- initial learning rate (default: {0.1})
  
  Returns:
      torch model -- last or best model
  """  
  # change net to training mode
  net.train()
  # use gpu to train
  net.cuda()
  # loss of training
  criterion = nn.CrossEntropyLoss()
  
  optimizer = torch.optim.SGD(
      net.parameters(), 
      lr=init_lr,
      momentum=0.9,
      weight_decay=1e-4)
  scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, threshold=0.001, patience=7)

  validation_scores = []
  
  os.makedirs("models", exist_ok=True)
  saving_path_template = "models/model_epoch%s.dms"

  for epoch in range(epoches):  # loop over the dataset multiple times
      saving_name = saving_path_template%epoch
      
      loss_avg = AverageMeter()
      accuracy_score_avg = AverageMeter()

      for i, data in enumerate(trainloader, 1):
          # get the inputs; data is a list of [inputs, labels]
          inputs, labels = data
          current_batch_size = len(labels)
          if compression_f:
            inputs = compression_f(inputs)
          inputs, labels = inputs.cuda(), labels.cuda()

          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = net(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          micro_acc_score = accuracy_minibatch(outputs, labels)

          loss_avg.update(loss.item()*current_batch_size, current_batch_size)
          accuracy_score_avg.update(micro_acc_score*current_batch_size, current_batch_size)

      if verbose:
        print(saving_name)
        print('loss {:.3}'.format(loss_avg.average()))
        print('current lr {:.3e}'.format(optimizer.param_groups[0]['lr']))
        print("__________________")
      
      # clear memory 
      gc.collect()
      torch.cuda.empty_cache()  
      
      validation_score = validate(net, valloader, logger=logger, verbose=verbose, compression_f=compression_f)
      accuracy = validation_score['val_accuracy']
      
      validation_scores.append(accuracy)
      torch.save(net.state_dict(), saving_name)
      
      if logger:
        logger.log_scalar("ce_loss", loss_avg.average())
        logger.log_scalar("accuracy", accuracy_score_avg.average())
        logger.step()

      scheduler.step(validation_score['val_ce_loss'])

  best_epoch = np.argmax(validation_scores)
  if return_best:
    choosen_epoch = best_epoch
  else:
    choosen_epoch = epoch
  if verbose:
    print("choosen epoch:", choosen_epoch, ",", "score:", validation_scores[choosen_epoch])
    print("best epoch:", best_epoch, ",", "score:", validation_scores[best_epoch])
  model_name = saving_path_template%choosen_epoch
  net.load_state_dict(torch.load(model_name))
  return net

# %%
for net, name in [
                  (resnet7(), "resnet7_classic.pt"), 
                  (resnet20(), "resnet20_classic.pt"), 
                  (resnet32(), "resnet32_classic.pt"), 
                  ]:
  logger = TensorBoardLogger("logs", dataset_name, name[:-11], name)
  net = train_classic_approach(net, trainloader, valloader, logger=logger, return_best=True)
  print("-----------------")
  print(name)
  score_test = validate(net, testloader, prename="test")
  score_val = validate(net, valloader, prename="val")
  validate(net, trainloader, prename="train")
  print("----------------")
  hparams = {"experiment_name":name, "teacher":"no", "dataset":dataset_name}
  for key, value in score_val.items():
    hparams["student/"+key] = value
    hparams["teacher/"+key] = 0
  for key, value in score_test.items():
    hparams["student/"+key] = value
    hparams["teacher/"+key] = 0

  torch.save(net.state_dict(),name)
  upload_model(name, name)
  upload_logs()
# Out:
# models/model_epoch0.dms
# loss 3.95
# current lr 1.000e-01
# __________________
# val_accuracy 0.1272
# val_ce_loss 3.7104481154123943
# __________________
# models/model_epoch1.dms
# loss 3.39
# current lr 1.000e-01
# __________________
# val_accuracy 0.20026666666666668
# val_ce_loss 3.2960775822957356
# __________________
# models/model_epoch2.dms
# loss 3.03
# current lr 1.000e-01
# __________________
# val_accuracy 0.23933333333333334
# val_ce_loss 3.121228690210978
# __________________
# models/model_epoch3.dms
# loss 2.81
# current lr 1.000e-01
# __________________
# val_accuracy 0.28546666666666665
# val_ce_loss 2.9182481405893963
# __________________
# models/model_epoch4.dms
# loss 2.63
# current lr 1.000e-01
# __________________
# val_accuracy 0.2809333333333333
# val_ce_loss 2.893646093114217
# __________________
# models/model_epoch5.dms
# loss 2.5
# current lr 1.000e-01
# __________________
# val_accuracy 0.3392
# val_ce_loss 2.585535514831543
# __________________
# models/model_epoch6.dms
# loss 2.38
# current lr 1.000e-01
# __________________
# val_accuracy 0.3138666666666667
# val_ce_loss 2.842960785547892
# __________________
# models/model_epoch7.dms
# loss 2.31
# current lr 1.000e-01
# __________________
# val_accuracy 0.374
# val_ce_loss 2.433275252787272
# __________________
# models/model_epoch8.dms
# loss 2.25
# current lr 1.000e-01
# __________________
# val_accuracy 0.362
# val_ce_loss 2.4848675813039143
# __________________
# models/model_epoch9.dms
# loss 2.19
# current lr 1.000e-01
# __________________
# val_accuracy 0.40746666666666664
# val_ce_loss 2.3372831329345702
# __________________
# models/model_epoch10.dms
# loss 2.13
# current lr 1.000e-01
# __________________
# val_accuracy 0.39413333333333334
# val_ce_loss 2.3776502946217857
# __________________
# models/model_epoch11.dms
# loss 2.1
# current lr 1.000e-01
# __________________
# val_accuracy 0.38426666666666665
# val_ce_loss 2.3892248845418296
# __________________
# models/model_epoch12.dms
# loss 2.07
# current lr 1.000e-01
# __________________
# val_accuracy 0.3990666666666667
# val_ce_loss 2.40345811475118
# __________________
# models/model_epoch13.dms
# loss 2.04
# current lr 1.000e-01
# __________________
# val_accuracy 0.4049333333333333
# val_ce_loss 2.3619240469614664
# __________________
# models/model_epoch14.dms
# loss 2.01
# current lr 1.000e-01
# __________________
# val_accuracy 0.3974666666666667
# val_ce_loss 2.3987200963338218
# __________________
# models/model_epoch15.dms
# loss 2.0
# current lr 1.000e-01
# __________________
# val_accuracy 0.38986666666666664
# val_ce_loss 2.5158645707448324
# __________________
# models/model_epoch16.dms
# loss 1.97
# current lr 1.000e-01
# __________________
# val_accuracy 0.39986666666666665
# val_ce_loss 2.375925178146362
# __________________
# models/model_epoch17.dms
# loss 1.95
# current lr 1.000e-01
# __________________
# val_accuracy 0.4252
# val_ce_loss 2.2742220736185708
# __________________
# models/model_epoch18.dms
# loss 1.93
# current lr 1.000e-01
# __________________
# val_accuracy 0.42893333333333333
# val_ce_loss 2.1934230553944905
# __________________
# models/model_epoch19.dms
# loss 1.92
# current lr 1.000e-01
# __________________
# val_accuracy 0.43266666666666664
# val_ce_loss 2.253852425765991
# __________________
# models/model_epoch20.dms
# loss 1.9
# current lr 1.000e-01
# __________________
# val_accuracy 0.39453333333333335
# val_ce_loss 2.4509482620239256
# __________________
# models/model_epoch21.dms
# loss 1.89
# current lr 1.000e-01
# __________________
# val_accuracy 0.4496
# val_ce_loss 2.0814002248764036
# __________________
# models/model_epoch22.dms
# loss 1.88
# current lr 1.000e-01
# __________________
# val_accuracy 0.3964
# val_ce_loss 2.5008020860036213
# __________________
# models/model_epoch23.dms
# loss 1.87
# current lr 1.000e-01
# __________________
# val_accuracy 0.454
# val_ce_loss 2.094449765396118
# __________________
# models/model_epoch24.dms
# loss 1.86
# current lr 1.000e-01
# __________________
# val_accuracy 0.4554666666666667
# val_ce_loss 2.118703061803182
# __________________
# models/model_epoch25.dms
# loss 1.85
# current lr 1.000e-01
# __________________
# val_accuracy 0.43933333333333335
# val_ce_loss 2.229169621785482
# __________________
# models/model_epoch26.dms
# loss 1.85
# current lr 1.000e-01
# __________________
# val_accuracy 0.43466666666666665
# val_ce_loss 2.185696786117554
# __________________
# models/model_epoch27.dms
# loss 1.83
# current lr 1.000e-01
# __________________
# val_accuracy 0.4088
# val_ce_loss 2.442351606877645
# __________________
# models/model_epoch28.dms
# loss 1.82
# current lr 1.000e-01
# __________________
# val_accuracy 0.43066666666666664
# val_ce_loss 2.243659933344523
# __________________
# models/model_epoch29.dms
# loss 1.82
# current lr 1.000e-01
# __________________
# val_accuracy 0.46413333333333334
# val_ce_loss 2.0660240277608235
# __________________
# models/model_epoch30.dms
# loss 1.81
# current lr 1.000e-01
# __________________
# val_accuracy 0.4348
# val_ce_loss 2.2321018672943116
# __________________
# models/model_epoch31.dms
# loss 1.81
# current lr 1.000e-01
# __________________
# val_accuracy 0.47253333333333336
# val_ce_loss 2.028864535077413
# __________________
# models/model_epoch32.dms
# loss 1.81
# current lr 1.000e-01
# __________________
# val_accuracy 0.44226666666666664
# val_ce_loss 2.2169648794809977
# __________________
# models/model_epoch33.dms
# loss 1.79
# current lr 1.000e-01
# __________________
# val_accuracy 0.45066666666666666
# val_ce_loss 2.1582055766423545
# __________________
# models/model_epoch34.dms
# loss 1.79
# current lr 1.000e-01
# __________________
# val_accuracy 0.47053333333333336
# val_ce_loss 2.065618859354655
# __________________
# models/model_epoch35.dms
# loss 1.78
# current lr 1.000e-01
# __________________
# val_accuracy 0.44733333333333336
# val_ce_loss 2.135739716529846
# __________________
# models/model_epoch36.dms
# loss 1.79
# current lr 1.000e-01
# __________________
# val_accuracy 0.4584
# val_ce_loss 2.117347769292196
# __________________
# models/model_epoch37.dms
# loss 1.77
# current lr 1.000e-01
# __________________
# val_accuracy 0.4672
# val_ce_loss 2.046347717221578
# __________________
# models/model_epoch38.dms
# loss 1.77
# current lr 1.000e-01
# __________________
# val_accuracy 0.45693333333333336
# val_ce_loss 2.1509087604522703
# __________________
# models/model_epoch39.dms
# loss 1.77
# current lr 1.000e-01
# __________________
# val_accuracy 0.4165333333333333
# val_ce_loss 2.4031005718866982
# __________________
# models/model_epoch40.dms
# loss 1.52
# current lr 1.000e-02
# __________________
# val_accuracy 0.5542666666666667
# val_ce_loss 1.6469934865951539
# __________________
# models/model_epoch41.dms
# loss 1.46
# current lr 1.000e-02
# __________________
# val_accuracy 0.5548
# val_ce_loss 1.6422016333262126
# __________________
# models/model_epoch42.dms
# loss 1.44
# current lr 1.000e-02
# __________________
# val_accuracy 0.5616
# val_ce_loss 1.6073970733642577
# __________________
# models/model_epoch43.dms
# loss 1.42
# current lr 1.000e-02
# __________________
# val_accuracy 0.56
# val_ce_loss 1.6252112749735514
# __________________
# models/model_epoch44.dms
# loss 1.41
# current lr 1.000e-02
# __________________
# val_accuracy 0.562
# val_ce_loss 1.6248810618082683
# __________________
# models/model_epoch45.dms
# loss 1.41
# current lr 1.000e-02
# __________________
# val_accuracy 0.5656
# val_ce_loss 1.5973443248112997
# __________________
# models/model_epoch46.dms
# loss 1.4
# current lr 1.000e-02
# __________________
# val_accuracy 0.5594666666666667
# val_ce_loss 1.6328303151448569
# __________________
# models/model_epoch47.dms
# loss 1.39
# current lr 1.000e-02
# __________________
# val_accuracy 0.5657333333333333
# val_ce_loss 1.5984969604651134
# __________________
# models/model_epoch48.dms
# loss 1.39
# current lr 1.000e-02
# __________________
# val_accuracy 0.5668
# val_ce_loss 1.5908858212471009
# __________________
# models/model_epoch49.dms
# loss 1.38
# current lr 1.000e-02
# __________________
# val_accuracy 0.5685333333333333
# val_ce_loss 1.6047735767364502
# __________________
# models/model_epoch50.dms
# loss 1.38
# current lr 1.000e-02
# __________________
# val_accuracy 0.5636
# val_ce_loss 1.613295587380727
# __________________
# models/model_epoch51.dms
# loss 1.38
# current lr 1.000e-02
# __________________
# val_accuracy 0.5665333333333333
# val_ce_loss 1.5952061992645263
# __________________
# models/model_epoch52.dms
# loss 1.37
# current lr 1.000e-02
# __________________
# val_accuracy 0.5692
# val_ce_loss 1.5897640104929607
# __________________
# models/model_epoch53.dms
# loss 1.36
# current lr 1.000e-02
# __________________
# val_accuracy 0.566
# val_ce_loss 1.605272922261556
# __________________
# models/model_epoch54.dms
# loss 1.37
# current lr 1.000e-02
# __________________
# val_accuracy 0.5632
# val_ce_loss 1.61084204454422
# __________________
# models/model_epoch55.dms
# loss 1.36
# current lr 1.000e-02
# __________________
# val_accuracy 0.5688
# val_ce_loss 1.600244145266215
# __________________
# models/model_epoch56.dms
# loss 1.36
# current lr 1.000e-02
# __________________
# val_accuracy 0.5637333333333333
# val_ce_loss 1.5993774679819743
# __________________
# models/model_epoch57.dms
# loss 1.32
# current lr 1.000e-03
# __________________
# val_accuracy 0.5758666666666666
# val_ce_loss 1.552270135561625
# __________________
# models/model_epoch58.dms
# loss 1.31
# current lr 1.000e-03
# __________________
# val_accuracy 0.5789333333333333
# val_ce_loss 1.5477166668574016
# __________________
# models/model_epoch59.dms
# loss 1.31
# current lr 1.000e-03
# __________________
# val_accuracy 0.5752
# val_ce_loss 1.5625752381006877
# __________________
# models/model_epoch60.dms
# loss 1.31
# current lr 1.000e-03
# __________________
# val_accuracy 0.5768
# val_ce_loss 1.558662274424235
# __________________
# models/model_epoch61.dms
# loss 1.3
# current lr 1.000e-03
# __________________
# val_accuracy 0.5713333333333334
# val_ce_loss 1.573421878941854
# __________________
# models/model_epoch62.dms
# loss 1.3
# current lr 1.000e-03
# __________________
# val_accuracy 0.5798666666666666
# val_ce_loss 1.5427271646181742
# __________________
# models/model_epoch63.dms
# loss 1.31
# current lr 1.000e-03
# __________________
# val_accuracy 0.5752
# val_ce_loss 1.5604327713648478
# __________________
# models/model_epoch64.dms
# loss 1.3
# current lr 1.000e-03
# __________________
# val_accuracy 0.5768
# val_ce_loss 1.554600887298584
# __________________
# models/model_epoch65.dms
# loss 1.3
# current lr 1.000e-03
# __________________
# val_accuracy 0.5754666666666667
# val_ce_loss 1.5556183327356974
# __________________
# models/model_epoch66.dms
# loss 1.3
# current lr 1.000e-03
# __________________
# val_accuracy 0.5761333333333334
# val_ce_loss 1.5543067132314046
# __________________
# models/model_epoch67.dms
# loss 1.3
# current lr 1.000e-03
# __________________
# val_accuracy 0.5774666666666667
# val_ce_loss 1.5574500764687855
# __________________
# models/model_epoch68.dms
# loss 1.29
# current lr 1.000e-03
# __________________
# val_accuracy 0.5792
# val_ce_loss 1.5543542433420816
# __________________
# models/model_epoch69.dms
# loss 1.3
# current lr 1.000e-03
# __________________
# val_accuracy 0.5764
# val_ce_loss 1.548155065981547
# __________________
# models/model_epoch70.dms
# loss 1.29
# current lr 1.000e-03
# __________________
# val_accuracy 0.5797333333333333
# val_ce_loss 1.5441190390268962
# __________________
# models/model_epoch71.dms
# loss 1.29
# current lr 1.000e-04
# __________________
# val_accuracy 0.5761333333333334
# val_ce_loss 1.556594544919332
# __________________
# models/model_epoch72.dms
# loss 1.29
# current lr 1.000e-04
# __________________
# val_accuracy 0.5741333333333334
# val_ce_loss 1.5644292168299356
# __________________
# models/model_epoch73.dms
# loss 1.29
# current lr 1.000e-04
# __________________
# val_accuracy 0.5761333333333334
# val_ce_loss 1.5445565830866497
# __________________
# models/model_epoch74.dms
# loss 1.29
# current lr 1.000e-04
# __________________
# val_accuracy 0.5753333333333334
# val_ce_loss 1.5530496834437053
# __________________
# models/model_epoch75.dms
# loss 1.29
# current lr 1.000e-04
# __________________
# val_accuracy 0.5726666666666667
# val_ce_loss 1.5470716426849365
# __________________
# models/model_epoch76.dms
# loss 1.29
# current lr 1.000e-04
# __________________
# val_accuracy 0.5788
# val_ce_loss 1.5401912348429363
# __________________
# models/model_epoch77.dms
# loss 1.29
# current lr 1.000e-04
# __________________
# val_accuracy 0.5785333333333333
# val_ce_loss 1.5551847772598266
# __________________
# models/model_epoch78.dms
# loss 1.3
# current lr 1.000e-04
# __________________
# val_accuracy 0.5768
# val_ce_loss 1.5443545202891031
# __________________
# models/model_epoch79.dms
# loss 1.29
# current lr 1.000e-04
# __________________
# val_accuracy 0.5749333333333333
# val_ce_loss 1.5599617389043172
# __________________
# models/model_epoch80.dms
# loss 1.29
# current lr 1.000e-04
# __________________
# val_accuracy 0.58
# val_ce_loss 1.5514127837498983
# __________________
# models/model_epoch81.dms
# loss 1.29
# current lr 1.000e-04
# __________________
# val_accuracy 0.5776
# val_ce_loss 1.5592575759569804
# __________________
# models/model_epoch82.dms
# loss 1.29
# current lr 1.000e-04
# __________________
# val_accuracy 0.5777333333333333
# val_ce_loss 1.541966357866923
# __________________
# models/model_epoch83.dms
# loss 1.29
# current lr 1.000e-04
# __________________
# val_accuracy 0.5737333333333333
# val_ce_loss 1.5559331197738648
# __________________
# models/model_epoch84.dms
# loss 1.29
# current lr 1.000e-04
# __________________
# val_accuracy 0.5756
# val_ce_loss 1.560923483022054
# __________________
# models/model_epoch85.dms
# loss 1.28
# current lr 1.000e-05
# __________________
# val_accuracy 0.5769333333333333
# val_ce_loss 1.557887772623698
# __________________
# models/model_epoch86.dms
# loss 1.29
# current lr 1.000e-05
# __________________
# val_accuracy 0.5768
# val_ce_loss 1.549828448486328
# __________________
# models/model_epoch87.dms
# loss 1.29
# current lr 1.000e-05
# __________________
# val_accuracy 0.5797333333333333
# val_ce_loss 1.5494212780634562
# __________________
# models/model_epoch88.dms
# loss 1.29
# current lr 1.000e-05
# __________________
# val_accuracy 0.5766666666666667
# val_ce_loss 1.543533003171285
# __________________
# models/model_epoch89.dms
# loss 1.29
# current lr 1.000e-05
# __________________
# val_accuracy 0.5766666666666667
# val_ce_loss 1.55923100121816
# __________________
# models/model_epoch90.dms
# loss 1.29
# current lr 1.000e-05
# __________________
# val_accuracy 0.5790666666666666
# val_ce_loss 1.5515062912623088
# __________________
# models/model_epoch91.dms
# loss 1.29
# current lr 1.000e-05
# __________________
# val_accuracy 0.5770666666666666
# val_ce_loss 1.5564342948277792
# __________________
# models/model_epoch92.dms
# loss 1.29
# current lr 1.000e-05
# __________________
# val_accuracy 0.5770666666666666
# val_ce_loss 1.5584478939056396
# __________________
# models/model_epoch93.dms
# loss 1.29
# current lr 1.000e-06
# __________________
# val_accuracy 0.576
# val_ce_loss 1.563233133983612
# __________________
# models/model_epoch94.dms
# loss 1.29
# current lr 1.000e-06
# __________________
# val_accuracy 0.5801333333333333
# val_ce_loss 1.5517885058085124
# __________________
# models/model_epoch95.dms
# loss 1.29
# current lr 1.000e-06
# __________________
# val_accuracy 0.5777333333333333
# val_ce_loss 1.5580240559895833
# __________________
# models/model_epoch96.dms
# loss 1.29
# current lr 1.000e-06
# __________________
# val_accuracy 0.5770666666666666
# val_ce_loss 1.5462089745839436
# __________________
# models/model_epoch97.dms
# loss 1.29
# current lr 1.000e-06
# __________________
# val_accuracy 0.5741333333333334
# val_ce_loss 1.5626073888142904
# __________________
# models/model_epoch98.dms
# loss 1.29
# current lr 1.000e-06
# __________________
# val_accuracy 0.5737333333333333
# val_ce_loss 1.5564330760320029
# __________________
# models/model_epoch99.dms
# loss 1.29
# current lr 1.000e-06
# __________________
# val_accuracy 0.5793333333333334
# val_ce_loss 1.5510528674125672
# __________________
# models/model_epoch100.dms
# loss 1.29
# current lr 1.000e-06
# __________________
# val_accuracy 0.5764
# val_ce_loss 1.556717450841268
# __________________
# models/model_epoch101.dms
# loss 1.29
# current lr 1.000e-07
# __________________
# val_accuracy 0.5782666666666667
# val_ce_loss 1.5532535079956056
# __________________
# models/model_epoch102.dms
# loss 1.29
# current lr 1.000e-07
# __________________
# val_accuracy 0.5741333333333334
# val_ce_loss 1.5668099232991537
# __________________
# models/model_epoch103.dms
# loss 1.29
# current lr 1.000e-07
# __________________
# val_accuracy 0.5756
# val_ce_loss 1.5723772512118022
# __________________
# models/model_epoch104.dms
# loss 1.29
# current lr 1.000e-07
# __________________
# val_accuracy 0.5746666666666667
# val_ce_loss 1.5673591590245566
# __________________
# models/model_epoch105.dms
# loss 1.29
# current lr 1.000e-07
# __________________
# val_accuracy 0.5773333333333334
# val_ce_loss 1.5489683618545533
# __________________
# models/model_epoch106.dms
# loss 1.29
# current lr 1.000e-07
# __________________
# val_accuracy 0.5756
# val_ce_loss 1.5529126193364462
# __________________
# models/model_epoch107.dms
# loss 1.29
# current lr 1.000e-07
# __________________
# val_accuracy 0.5750666666666666
# val_ce_loss 1.5606708088556926
# __________________
# models/model_epoch108.dms
# loss 1.29
# current lr 1.000e-07
# __________________
# val_accuracy 0.5788
# val_ce_loss 1.5590905842463176
# __________________
# models/model_epoch109.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5776
# val_ce_loss 1.5482915196736653
# __________________
# models/model_epoch110.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5744
# val_ce_loss 1.5523571003595988
# __________________
# models/model_epoch111.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5758666666666666
# val_ce_loss 1.5522295692443848
# __________________
# models/model_epoch112.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5776
# val_ce_loss 1.5453400650024414
# __________________
# models/model_epoch113.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5766666666666667
# val_ce_loss 1.5529072642008463
# __________________
# models/model_epoch114.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5785333333333333
# val_ce_loss 1.545299619293213
# __________________
# models/model_epoch115.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5778666666666666
# val_ce_loss 1.545680221112569
# __________________
# models/model_epoch116.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5790666666666666
# val_ce_loss 1.547147521909078
# __________________
# models/model_epoch117.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5734666666666667
# val_ce_loss 1.5571805653254192
# __________________
# models/model_epoch118.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5745333333333333
# val_ce_loss 1.5724669541041056
# __________________
# models/model_epoch119.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5756
# val_ce_loss 1.5500705783843993
# __________________
# models/model_epoch120.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5738666666666666
# val_ce_loss 1.5442391244252522
# __________________
# models/model_epoch121.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5762666666666667
# val_ce_loss 1.5508766723632812
# __________________
# models/model_epoch122.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5745333333333333
# val_ce_loss 1.5522850555419923
# __________________
# models/model_epoch123.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5776
# val_ce_loss 1.5576687529246012
# __________________
# models/model_epoch124.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5748
# val_ce_loss 1.5578649644851685
# __________________
# models/model_epoch125.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5761333333333334
# val_ce_loss 1.545639575322469
# __________________
# models/model_epoch126.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5765333333333333
# val_ce_loss 1.5456147343317668
# __________________
# models/model_epoch127.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5798666666666666
# val_ce_loss 1.5485556564331056
# __________________
# models/model_epoch128.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5784
# val_ce_loss 1.5551351830164593
# __________________
# models/model_epoch129.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5754666666666667
# val_ce_loss 1.5609904728889465
# __________________
# models/model_epoch130.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5768
# val_ce_loss 1.5475060032526653
# __________________
# models/model_epoch131.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5810666666666666
# val_ce_loss 1.5431691965738932
# __________________
# models/model_epoch132.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5778666666666666
# val_ce_loss 1.5448164123853048
# __________________
# models/model_epoch133.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5768
# val_ce_loss 1.5581135815938314
# __________________
# models/model_epoch134.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5812
# val_ce_loss 1.5389678131103515
# __________________
# models/model_epoch135.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5808
# val_ce_loss 1.5480960199991862
# __________________
# models/model_epoch136.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.582
# val_ce_loss 1.5484538975397746
# __________________
# models/model_epoch137.dms
# loss 1.3
# current lr 1.000e-08
# __________________
# val_accuracy 0.5734666666666667
# val_ce_loss 1.5576090770721436
# __________________
# models/model_epoch138.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5765333333333333
# val_ce_loss 1.5653551865259807
# __________________
# models/model_epoch139.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5810666666666666
# val_ce_loss 1.5456406878789266
# __________________
# models/model_epoch140.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5754666666666667
# val_ce_loss 1.5483578420639037
# __________________
# models/model_epoch141.dms
# loss 1.3
# current lr 1.000e-08
# __________________
# val_accuracy 0.5749333333333333
# val_ce_loss 1.54798734404246
# __________________
# models/model_epoch142.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5761333333333334
# val_ce_loss 1.5441487419764202
# __________________
# models/model_epoch143.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5761333333333334
# val_ce_loss 1.5746460995992024
# __________________
# models/model_epoch144.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5713333333333334
# val_ce_loss 1.568675822321574
# __________________
# models/model_epoch145.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5762666666666667
# val_ce_loss 1.5574892508824667
# __________________
# models/model_epoch146.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5761333333333334
# val_ce_loss 1.550858514881134
# __________________
# models/model_epoch147.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5758666666666666
# val_ce_loss 1.551277375380198
# __________________
# models/model_epoch148.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5749333333333333
# val_ce_loss 1.570468160120646
# __________________
# models/model_epoch149.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5757333333333333
# val_ce_loss 1.5621426055908203
# __________________
# models/model_epoch150.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5774666666666667
# val_ce_loss 1.5407634565353394
# __________________
# models/model_epoch151.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.58
# val_ce_loss 1.550410715230306
# __________________
# models/model_epoch152.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5782666666666667
# val_ce_loss 1.5490382090250652
# __________________
# models/model_epoch153.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5758666666666666
# val_ce_loss 1.5567892737706501
# __________________
# models/model_epoch154.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5784
# val_ce_loss 1.5571869098027546
# __________________
# models/model_epoch155.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5774666666666667
# val_ce_loss 1.5551315277099609
# __________________
# models/model_epoch156.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5776
# val_ce_loss 1.5509072107950845
# __________________
# models/model_epoch157.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5716
# val_ce_loss 1.5566589406967164
# __________________
# models/model_epoch158.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5770666666666666
# val_ce_loss 1.5548162619272867
# __________________
# models/model_epoch159.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5814666666666667
# val_ce_loss 1.546442921892802
# __________________
# models/model_epoch160.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5772
# val_ce_loss 1.5565770288149516
# __________________
# models/model_epoch161.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5785333333333333
# val_ce_loss 1.5553021458943685
# __________________
# models/model_epoch162.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5768
# val_ce_loss 1.543568582280477
# __________________
# models/model_epoch163.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5781333333333334
# val_ce_loss 1.558233740234375
# __________________
# models/model_epoch164.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5778666666666666
# val_ce_loss 1.5536117884318035
# __________________
# models/model_epoch165.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5762666666666667
# val_ce_loss 1.5444373598098755
# __________________
# models/model_epoch166.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5766666666666667
# val_ce_loss 1.5621975369771322
# __________________
# models/model_epoch167.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5745333333333333
# val_ce_loss 1.5521468973795574
# __________________
# models/model_epoch168.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5781333333333334
# val_ce_loss 1.5416574498494466
# __________________
# models/model_epoch169.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5773333333333334
# val_ce_loss 1.5466630467732747
# __________________
# models/model_epoch170.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5770666666666666
# val_ce_loss 1.5488169662475586
# __________________
# models/model_epoch171.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.576
# val_ce_loss 1.5499999736785888
# __________________
# models/model_epoch172.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5774666666666667
# val_ce_loss 1.5515552083969115
# __________________
# models/model_epoch173.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5716
# val_ce_loss 1.5629180618921916
# __________________
# models/model_epoch174.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5762666666666667
# val_ce_loss 1.552258093738556
# __________________
# models/model_epoch175.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5754666666666667
# val_ce_loss 1.5584276669184367
# __________________
# models/model_epoch176.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5748
# val_ce_loss 1.554097244389852
# __________________
# models/model_epoch177.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5754666666666667
# val_ce_loss 1.551150954437256
# __________________
# models/model_epoch178.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5781333333333334
# val_ce_loss 1.546205583190918
# __________________
# models/model_epoch179.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5750666666666666
# val_ce_loss 1.5644825822194417
# __________________
# models/model_epoch180.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5744
# val_ce_loss 1.5632704648653666
# __________________
# models/model_epoch181.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5754666666666667
# val_ce_loss 1.5523272064208984
# __________________
# models/model_epoch182.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5766666666666667
# val_ce_loss 1.551938315264384
# __________________
# models/model_epoch183.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5766666666666667
# val_ce_loss 1.544977752749125
# __________________
# models/model_epoch184.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5762666666666667
# val_ce_loss 1.5515018649419148
# __________________
# models/model_epoch185.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5801333333333333
# val_ce_loss 1.5566110160191853
# __________________
# models/model_epoch186.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5761333333333334
# val_ce_loss 1.5606992402394613
# __________________
# models/model_epoch187.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5738666666666666
# val_ce_loss 1.5558927808443705
# __________________
# models/model_epoch188.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5786666666666667
# val_ce_loss 1.5502969344456992
# __________________
# models/model_epoch189.dms
# loss 1.3
# current lr 1.000e-08
# __________________
# val_accuracy 0.5770666666666666
# val_ce_loss 1.5452615801493328
# __________________
# models/model_epoch190.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5773333333333334
# val_ce_loss 1.545344935830434
# __________________
# models/model_epoch191.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5773333333333334
# val_ce_loss 1.5526403029759726
# __________________
# models/model_epoch192.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5769333333333333
# val_ce_loss 1.5617504322687785
# __________________
# models/model_epoch193.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5786666666666667
# val_ce_loss 1.555504449526469
# __________________
# models/model_epoch194.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5756
# val_ce_loss 1.5498629464467366
# __________________
# models/model_epoch195.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5778666666666666
# val_ce_loss 1.5552731679280598
# __________________
# models/model_epoch196.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5778666666666666
# val_ce_loss 1.5471599027633667
# __________________
# models/model_epoch197.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5789333333333333
# val_ce_loss 1.5534388100941976
# __________________
# models/model_epoch198.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5758666666666666
# val_ce_loss 1.5499405109405517
# __________________
# models/model_epoch199.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5777333333333333
# val_ce_loss 1.5472664611816407
# __________________
# models/model_epoch200.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5797333333333333
# val_ce_loss 1.5500660276412963
# __________________
# models/model_epoch201.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5758666666666666
# val_ce_loss 1.552195250892639
# __________________
# models/model_epoch202.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.576
# val_ce_loss 1.542633055114746
# __________________
# models/model_epoch203.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5752
# val_ce_loss 1.5538724948883056
# __________________
# models/model_epoch204.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5786666666666667
# val_ce_loss 1.5440344359079996
# __________________
# models/model_epoch205.dms
# loss 1.3
# current lr 1.000e-08
# __________________
# val_accuracy 0.5756
# val_ce_loss 1.554596236673991
# __________________
# models/model_epoch206.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5737333333333333
# val_ce_loss 1.5520073551177977
# __________________
# models/model_epoch207.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5797333333333333
# val_ce_loss 1.556056646792094
# __________________
# models/model_epoch208.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5769333333333333
# val_ce_loss 1.5506674430211385
# __________________
# models/model_epoch209.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5762666666666667
# val_ce_loss 1.5622159324645997
# __________________
# models/model_epoch210.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5724
# val_ce_loss 1.5539391059557597
# __________________
# models/model_epoch211.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5790666666666666
# val_ce_loss 1.554262044652303
# __________________
# models/model_epoch212.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5764
# val_ce_loss 1.5612381140232086
# __________________
# models/model_epoch213.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5773333333333334
# val_ce_loss 1.558411829884847
# __________________
# models/model_epoch214.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.574
# val_ce_loss 1.5563119674682617
# __________________
# models/model_epoch215.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5749333333333333
# val_ce_loss 1.5546238726298014
# __________________
# models/model_epoch216.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5781333333333334
# val_ce_loss 1.5550527994155883
# __________________
# models/model_epoch217.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5766666666666667
# val_ce_loss 1.5556276646931966
# __________________
# models/model_epoch218.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5754666666666667
# val_ce_loss 1.549412931696574
# __________________
# models/model_epoch219.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5789333333333333
# val_ce_loss 1.5632835728327432
# __________________
# models/model_epoch220.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5778666666666666
# val_ce_loss 1.542456708463033
# __________________
# models/model_epoch221.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5736
# val_ce_loss 1.5532226394653321
# __________________
# models/model_epoch222.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5734666666666667
# val_ce_loss 1.55339050394694
# __________________
# models/model_epoch223.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.572
# val_ce_loss 1.5576915933609008
# __________________
# models/model_epoch224.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5754666666666667
# val_ce_loss 1.5514144278208415
# __________________
# models/model_epoch225.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5764
# val_ce_loss 1.5449300254185994
# __________________
# models/model_epoch226.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.576
# val_ce_loss 1.5500294169743856
# __________________
# models/model_epoch227.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5773333333333334
# val_ce_loss 1.5455712480862935
# __________________
# models/model_epoch228.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5757333333333333
# val_ce_loss 1.5499209344863891
# __________________
# models/model_epoch229.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5781333333333334
# val_ce_loss 1.5466904325167339
# __________________
# models/model_epoch230.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5761333333333334
# val_ce_loss 1.5490937423706055
# __________________
# models/model_epoch231.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5762666666666667
# val_ce_loss 1.5564266091664631
# __________________
# models/model_epoch232.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5774666666666667
# val_ce_loss 1.5526081910451253
# __________________
# models/model_epoch233.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5738666666666666
# val_ce_loss 1.5480605405171712
# __________________
# models/model_epoch234.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5810666666666666
# val_ce_loss 1.5444121571858724
# __________________
# models/model_epoch235.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5730666666666666
# val_ce_loss 1.5681347532272338
# __________________
# models/model_epoch236.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5772
# val_ce_loss 1.5537607761065164
# __________________
# models/model_epoch237.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5797333333333333
# val_ce_loss 1.546422392018636
# __________________
# models/model_epoch238.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5757333333333333
# val_ce_loss 1.5519590856552123
# __________________
# models/model_epoch239.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5729333333333333
# val_ce_loss 1.5703264887491861
# __________________
# models/model_epoch240.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5781333333333334
# val_ce_loss 1.5522094307899474
# __________________
# models/model_epoch241.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5792
# val_ce_loss 1.5477655314127605
# __________________
# models/model_epoch242.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5722666666666667
# val_ce_loss 1.577496735572815
# __________________
# models/model_epoch243.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5782666666666667
# val_ce_loss 1.5513294139862062
# __________________
# models/model_epoch244.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5750666666666666
# val_ce_loss 1.5505274278640746
# __________________
# models/model_epoch245.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5816
# val_ce_loss 1.5526961732228597
# __________________
# models/model_epoch246.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5729333333333333
# val_ce_loss 1.5474865772247315
# __________________
# models/model_epoch247.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5786666666666667
# val_ce_loss 1.5385230987548828
# __________________
# models/model_epoch248.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5776
# val_ce_loss 1.5524134155273437
# __________________
# models/model_epoch249.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5788
# val_ce_loss 1.5483618145624796
# __________________
# models/model_epoch250.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5808
# val_ce_loss 1.5421657267888387
# __________________
# models/model_epoch251.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5782666666666667
# val_ce_loss 1.5577736661275228
# __________________
# models/model_epoch252.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5806666666666667
# val_ce_loss 1.550964552307129
# __________________
# models/model_epoch253.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5765333333333333
# val_ce_loss 1.5644139464696247
# __________________
# models/model_epoch254.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5749333333333333
# val_ce_loss 1.549799183209737
# __________________
# models/model_epoch255.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5757333333333333
# val_ce_loss 1.5595913228352865
# __________________
# models/model_epoch256.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5741333333333334
# val_ce_loss 1.5528188488006591
# __________________
# models/model_epoch257.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5801333333333333
# val_ce_loss 1.55088711382548
# __________________
# models/model_epoch258.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5758666666666666
# val_ce_loss 1.5609915379842123
# __________________
# models/model_epoch259.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5794666666666667
# val_ce_loss 1.550670570119222
# __________________
# models/model_epoch260.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5789333333333333
# val_ce_loss 1.553647831662496
# __________________
# models/model_epoch261.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5749333333333333
# val_ce_loss 1.5567348397572836
# __________________
# models/model_epoch262.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5784
# val_ce_loss 1.5431717692057292
# __________________
# models/model_epoch263.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5774666666666667
# val_ce_loss 1.5446114775339763
# __________________
# models/model_epoch264.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5773333333333334
# val_ce_loss 1.5363199789683024
# __________________
# models/model_epoch265.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5789333333333333
# val_ce_loss 1.5587181940078736
# __________________
# models/model_epoch266.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5766666666666667
# val_ce_loss 1.5526641830444337
# __________________
# models/model_epoch267.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5770666666666666
# val_ce_loss 1.5578321018854777
# __________________
# models/model_epoch268.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5777333333333333
# val_ce_loss 1.5467298075993856
# __________________
# models/model_epoch269.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.578
# val_ce_loss 1.5475976837158203
# __________________
# models/model_epoch270.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5776
# val_ce_loss 1.5453069175084433
# __________________
# models/model_epoch271.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5766666666666667
# val_ce_loss 1.549200542004903
# __________________
# models/model_epoch272.dms
# loss 1.3
# current lr 1.000e-08
# __________________
# val_accuracy 0.576
# val_ce_loss 1.5519108790079752
# __________________
# models/model_epoch273.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5802666666666667
# val_ce_loss 1.542671778424581
# __________________
# models/model_epoch274.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5758666666666666
# val_ce_loss 1.5531985529581707
# __________________
# models/model_epoch275.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5786666666666667
# val_ce_loss 1.5552610418955486
# __________________
# models/model_epoch276.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5806666666666667
# val_ce_loss 1.5483313607851665
# __________________
# models/model_epoch277.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5773333333333334
# val_ce_loss 1.5524745717366537
# __________________
# models/model_epoch278.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5789333333333333
# val_ce_loss 1.5429852403640747
# __________________
# models/model_epoch279.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5730666666666666
# val_ce_loss 1.5534282956441243
# __________________
# models/model_epoch280.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.576
# val_ce_loss 1.5479785432497661
# __________________
# models/model_epoch281.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5725333333333333
# val_ce_loss 1.5713546072642008
# __________________
# models/model_epoch282.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5785333333333333
# val_ce_loss 1.5490254838943482
# __________________
# models/model_epoch283.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5774666666666667
# val_ce_loss 1.5487064961751302
# __________________
# models/model_epoch284.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5778666666666666
# val_ce_loss 1.5565365364074708
# __________________
# models/model_epoch285.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5750666666666666
# val_ce_loss 1.5555562058766683
# __________________
# models/model_epoch286.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5764
# val_ce_loss 1.5453538342793782
# __________________
# models/model_epoch287.dms
# loss 1.28
# current lr 1.000e-08
# __________________
# val_accuracy 0.5757333333333333
# val_ce_loss 1.556662551689148
# __________________
# models/model_epoch288.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5756
# val_ce_loss 1.564986993376414
# __________________
# models/model_epoch289.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.578
# val_ce_loss 1.5520769119262696
# __________________
# models/model_epoch290.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.578
# val_ce_loss 1.549461359723409
# __________________
# models/model_epoch291.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5758666666666666
# val_ce_loss 1.5582724209785461
# __________________
# models/model_epoch292.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5765333333333333
# val_ce_loss 1.5583187175750732
# __________________
# models/model_epoch293.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5741333333333334
# val_ce_loss 1.5647950754801432
# __________________
# models/model_epoch294.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5773333333333334
# val_ce_loss 1.544700737953186
# __________________
# models/model_epoch295.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5744
# val_ce_loss 1.5636737052281697
# __________________
# models/model_epoch296.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5758666666666666
# val_ce_loss 1.5552507028579712
# __________________
# models/model_epoch297.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5749333333333333
# val_ce_loss 1.5586090934117636
# __________________
# models/model_epoch298.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5802666666666667
# val_ce_loss 1.5454681065241496
# __________________
# models/model_epoch299.dms
# loss 1.29
# current lr 1.000e-08
# __________________
# val_accuracy 0.5754666666666667
# val_ce_loss 1.552036268488566
# __________________
# choosen epoch: 136 , score: 0.582
# best epoch: 136 , score: 0.582
# -----------------
# resnet7_classic.pt
# test_accuracy 0.5771
# test_ce_loss 1.5630531330108643
# __________________
# val_accuracy 0.582
# val_ce_loss 1.548453929011027
# __________________
# train_accuracy 0.6493882352941176
# train_ce_loss 1.247445762724035
# __________________
# ----------------
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
